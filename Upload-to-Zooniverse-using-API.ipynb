# %% [markdown]
# # Upload subject sets to Zooniverse using the Panoptes client

# %% [markdown]
# See the [Panoptes-client documentation](https://panoptes-python-client.readthedocs.io/en/v1.1/index.html#).

# %%
import os
import glob
import re
import io
from PIL import Image
from panoptes_client import Panoptes, Project, SubjectSet, Subject
from credentials import ZOONIVERSE_USER, ZOONIVERSE_PW

# %%
Panoptes.connect(username=ZOONIVERSE_USER, password=ZOONIVERSE_PW)

# %%
project = Project.find('8678')
project.title
# Out:
# 'Sydney Stock Exchange'

# %% [markdown]
# ## Create a new subject set

# %%
# New subject set
subject_set = SubjectSet()

subject_set.links.project = project
subject_set.display_name = 'Assorted headers'

subject_set.save()
# Out:
# {'subject_sets': [{'id': '77733',
#    'display_name': 'Assorted headers',
#    'set_member_subjects_count': 0,
#    'metadata': {},
#    'created_at': '2019-09-04T02:29:13.466Z',
#    'updated_at': '2019-09-04T02:29:13.466Z',
#    'href': '/subject_sets/77733',
#    'links': {'project': '8678', 'workflows': [], 'subjects': []}}],
#  'links': {'subject_sets.project': {'href': '/projects/{subject_sets.project}',
#    'type': 'projects'},
#   'subject_sets.workflows': {'href': '/workflows?subject_set_id={subject_sets.id}',
#    'type': 'workflows'}},
#  'meta': {'subject_sets': {'page': 1,
#    'page_size': 20,
#    'count': 1,
#    'include': [],
#    'page_count': 1,
#    'previous_page': None,
#    'next_page': None,
#    'first_href': '/subject_sets',
#    'previous_href': None,
#    'next_href': None,
#    'last_href': '/subject_sets'}}}

# %% [markdown]
# ## Get and existing subject set

# %%
subject_set = SubjectSet.find('76903')
subject_set.display_name
# Out:
# '1929 headers'

# %% [markdown]
# ## Upload subjects to a subject set
#
# Generate a list of items from a directory of images. Each item has the following fields:
#
# * `image_path` – full path to image
# * `image_name` – image file name
# * `volume` – volume identifier
# * `volume_number` – numeric
# * `page_number` – numeric

# %%
file_pattern = '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/*header.jpg'
image_files = glob.glob(file_pattern)
data = []
for image_file in image_files:
    image_path = image_file
    image_name = image_file.split('/')[-1]
    volume = re.search(r'(N193-\d+)_', image_name).group(1)
    volume_number = int(volume.split('-')[1])
    page_number = int(re.search(r'N193-\d+_(\d+)', image_name).group(1))
    data.append({'image_path': image_path, 'image_name': image_name, 'volume': volume, 'volume_number': volume_number, 'page_number': page_number})

# %%
# View the results
data
# Out:
# [{'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-121_0038-header.jpg',
#   'image_name': 'N193-121_0038-header.jpg',
#   'volume': 'N193-121',
#   'volume_number': 121,
#   'page_number': 38},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-083_0117-header.jpg',
#   'image_name': 'N193-083_0117-header.jpg',
#   'volume': 'N193-083',
#   'volume_number': 83,
#   'page_number': 117},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-103_0317-header.jpg',
#   'image_name': 'N193-103_0317-header.jpg',
#   'volume': 'N193-103',
#   'volume_number': 103,
#   'page_number': 317},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-016_0172-header.jpg',
#   'image_name': 'N193-016_0172-header.jpg',
#   'volume': 'N193-016',
#   'volume_number': 16,
#   'page_number': 172},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-160_0369-header.jpg',
#   'image_name': 'N193-160_0369-header.jpg',
#   'volume': 'N193-160',
#   'volume_number': 160,
#   'page_number': 369},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-108_0180-header.jpg',
#   'image_name': 'N193-108_0180-header.jpg',
#   'volume': 'N193-108',
#   'volume_number': 108,
#   'page_number': 180},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-145_0240-header.jpg',
#   'image_name': 'N193-145_0240-header.jpg',
#   'volume': 'N193-145',
#   'volume_number': 145,
#   'page_number': 240},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-098_0100-header.jpg',
#   'image_name': 'N193-098_0100-header.jpg',
#   'volume': 'N193-098',
#   'volume_number': 98,
#   'page_number': 100},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-094_0085-header.jpg',
#   'image_name': 'N193-094_0085-header.jpg',
#   'volume': 'N193-094',
#   'volume_number': 94,
#   'page_number': 85},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-054_0160-header.jpg',
#   'image_name': 'N193-054_0160-header.jpg',
#   'volume': 'N193-054',
#   'volume_number': 54,
#   'page_number': 160},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-169_0377-header.jpg',
#   'image_name': 'N193-169_0377-header.jpg',
#   'volume': 'N193-169',
#   'volume_number': 169,
#   'page_number': 377},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-095_0273-header.jpg',
#   'image_name': 'N193-095_0273-header.jpg',
#   'volume': 'N193-095',
#   'volume_number': 95,
#   'page_number': 273},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-041_0147-header.jpg',
#   'image_name': 'N193-041_0147-header.jpg',
#   'volume': 'N193-041',
#   'volume_number': 41,
#   'page_number': 147},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-081_0095-header.jpg',
#   'image_name': 'N193-081_0095-header.jpg',
#   'volume': 'N193-081',
#   'volume_number': 81,
#   'page_number': 95},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-130_0204-header.jpg',
#   'image_name': 'N193-130_0204-header.jpg',
#   'volume': 'N193-130',
#   'volume_number': 130,
#   'page_number': 204},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-180_0102-header.jpg',
#   'image_name': 'N193-180_0102-header.jpg',
#   'volume': 'N193-180',
#   'volume_number': 180,
#   'page_number': 102},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-142_0107-header.jpg',
#   'image_name': 'N193-142_0107-header.jpg',
#   'volume': 'N193-142',
#   'volume_number': 142,
#   'page_number': 107},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-103_0256-header.jpg',
#   'image_name': 'N193-103_0256-header.jpg',
#   'volume': 'N193-103',
#   'volume_number': 103,
#   'page_number': 256},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-003_0155-header.jpg',
#   'image_name': 'N193-003_0155-header.jpg',
#   'volume': 'N193-003',
#   'volume_number': 3,
#   'page_number': 155},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-072_0115-header.jpg',
#   'image_name': 'N193-072_0115-header.jpg',
#   'volume': 'N193-072',
#   'volume_number': 72,
#   'page_number': 115},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-083_0056-header.jpg',
#   'image_name': 'N193-083_0056-header.jpg',
#   'volume': 'N193-083',
#   'volume_number': 83,
#   'page_number': 56},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-062_0034-header.jpg',
#   'image_name': 'N193-062_0034-header.jpg',
#   'volume': 'N193-062',
#   'volume_number': 62,
#   'page_number': 34},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-085_0246-header.jpg',
#   'image_name': 'N193-085_0246-header.jpg',
#   'volume': 'N193-085',
#   'volume_number': 85,
#   'page_number': 246},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-051_0172-header.jpg',
#   'image_name': 'N193-051_0172-header.jpg',
#   'volume': 'N193-051',
#   'volume_number': 51,
#   'page_number': 172},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-006_0112-header.jpg',
#   'image_name': 'N193-006_0112-header.jpg',
#   'volume': 'N193-006',
#   'volume_number': 6,
#   'page_number': 112},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-099_0057-header.jpg',
#   'image_name': 'N193-099_0057-header.jpg',
#   'volume': 'N193-099',
#   'volume_number': 99,
#   'page_number': 57},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-031_0111-header.jpg',
#   'image_name': 'N193-031_0111-header.jpg',
#   'volume': 'N193-031',
#   'volume_number': 31,
#   'page_number': 111},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-035_0229-header.jpg',
#   'image_name': 'N193-035_0229-header.jpg',
#   'volume': 'N193-035',
#   'volume_number': 35,
#   'page_number': 229},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-169_0083-header.jpg',
#   'image_name': 'N193-169_0083-header.jpg',
#   'volume': 'N193-169',
#   'volume_number': 169,
#   'page_number': 83},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-165_0419-header.jpg',
#   'image_name': 'N193-165_0419-header.jpg',
#   'volume': 'N193-165',
#   'volume_number': 165,
#   'page_number': 419},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-160_0189-header.jpg',
#   'image_name': 'N193-160_0189-header.jpg',
#   'volume': 'N193-160',
#   'volume_number': 160,
#   'page_number': 189},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-098_0089-header.jpg',
#   'image_name': 'N193-098_0089-header.jpg',
#   'volume': 'N193-098',
#   'volume_number': 98,
#   'page_number': 89},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-173_0200-header.jpg',
#   'image_name': 'N193-173_0200-header.jpg',
#   'volume': 'N193-173',
#   'volume_number': 173,
#   'page_number': 200},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-008_0229-header.jpg',
#   'image_name': 'N193-008_0229-header.jpg',
#   'volume': 'N193-008',
#   'volume_number': 8,
#   'page_number': 229},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-190_0076-header.jpg',
#   'image_name': 'N193-190_0076-header.jpg',
#   'volume': 'N193-190',
#   'volume_number': 190,
#   'page_number': 76},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-058_0250-header.jpg',
#   'image_name': 'N193-058_0250-header.jpg',
#   'volume': 'N193-058',
#   'volume_number': 58,
#   'page_number': 250},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-189_0095-header.jpg',
#   'image_name': 'N193-189_0095-header.jpg',
#   'volume': 'N193-189',
#   'volume_number': 189,
#   'page_number': 95},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-170_0248-header.jpg',
#   'image_name': 'N193-170_0248-header.jpg',
#   'volume': 'N193-170',
#   'volume_number': 170,
#   'page_number': 248},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-136_0076-header.jpg',
#   'image_name': 'N193-136_0076-header.jpg',
#   'volume': 'N193-136',
#   'volume_number': 136,
#   'page_number': 76},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-101_0042-header.jpg',
#   'image_name': 'N193-101_0042-header.jpg',
#   'volume': 'N193-101',
#   'volume_number': 101,
#   'page_number': 42},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-114_0113-header.jpg',
#   'image_name': 'N193-114_0113-header.jpg',
#   'volume': 'N193-114',
#   'volume_number': 114,
#   'page_number': 113},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-164_0099-header.jpg',
#   'image_name': 'N193-164_0099-header.jpg',
#   'volume': 'N193-164',
#   'volume_number': 164,
#   'page_number': 99},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-148_0486-header.jpg',
#   'image_name': 'N193-148_0486-header.jpg',
#   'volume': 'N193-148',
#   'volume_number': 148,
#   'page_number': 486},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-198_0195-header.jpg',
#   'image_name': 'N193-198_0195-header.jpg',
#   'volume': 'N193-198',
#   'volume_number': 198,
#   'page_number': 195},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-062_0175-header.jpg',
#   'image_name': 'N193-062_0175-header.jpg',
#   'volume': 'N193-062',
#   'volume_number': 62,
#   'page_number': 175},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-172_0268-header.jpg',
#   'image_name': 'N193-172_0268-header.jpg',
#   'volume': 'N193-172',
#   'volume_number': 172,
#   'page_number': 268},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-050_0039-header.jpg',
#   'image_name': 'N193-050_0039-header.jpg',
#   'volume': 'N193-050',
#   'volume_number': 50,
#   'page_number': 39},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-187_0259-header.jpg',
#   'image_name': 'N193-187_0259-header.jpg',
#   'volume': 'N193-187',
#   'volume_number': 187,
#   'page_number': 259},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-176_0167-header.jpg',
#   'image_name': 'N193-176_0167-header.jpg',
#   'volume': 'N193-176',
#   'volume_number': 176,
#   'page_number': 167},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-157_0255-header.jpg',
#   'image_name': 'N193-157_0255-header.jpg',
#   'volume': 'N193-157',
#   'volume_number': 157,
#   'page_number': 255},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-117_0284-header.jpg',
#   'image_name': 'N193-117_0284-header.jpg',
#   'volume': 'N193-117',
#   'volume_number': 117,
#   'page_number': 284},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-195_0373-header.jpg',
#   'image_name': 'N193-195_0373-header.jpg',
#   'volume': 'N193-195',
#   'volume_number': 195,
#   'page_number': 373},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-107_0279-header.jpg',
#   'image_name': 'N193-107_0279-header.jpg',
#   'volume': 'N193-107',
#   'volume_number': 107,
#   'page_number': 279},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-190_0181-header.jpg',
#   'image_name': 'N193-190_0181-header.jpg',
#   'volume': 'N193-190',
#   'volume_number': 190,
#   'page_number': 181},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-160_0203-header.jpg',
#   'image_name': 'N193-160_0203-header.jpg',
#   'volume': 'N193-160',
#   'volume_number': 160,
#   'page_number': 203},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-174_0298-header.jpg',
#   'image_name': 'N193-174_0298-header.jpg',
#   'volume': 'N193-174',
#   'volume_number': 174,
#   'page_number': 298},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-185_0191-header.jpg',
#   'image_name': 'N193-185_0191-header.jpg',
#   'volume': 'N193-185',
#   'volume_number': 185,
#   'page_number': 191},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-035_0194-header.jpg',
#   'image_name': 'N193-035_0194-header.jpg',
#   'volume': 'N193-035',
#   'volume_number': 35,
#   'page_number': 194},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-008_0080-header.jpg',
#   'image_name': 'N193-008_0080-header.jpg',
#   'volume': 'N193-008',
#   'volume_number': 8,
#   'page_number': 80},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-195_0444-header.jpg',
#   'image_name': 'N193-195_0444-header.jpg',
#   'volume': 'N193-195',
#   'volume_number': 195,
#   'page_number': 444},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-022_0125-header.jpg',
#   'image_name': 'N193-022_0125-header.jpg',
#   'volume': 'N193-022',
#   'volume_number': 22,
#   'page_number': 125},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-161_0068-header.jpg',
#   'image_name': 'N193-161_0068-header.jpg',
#   'volume': 'N193-161',
#   'volume_number': 161,
#   'page_number': 68},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-009_0182-header.jpg',
#   'image_name': 'N193-009_0182-header.jpg',
#   'volume': 'N193-009',
#   'volume_number': 9,
#   'page_number': 182},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-031_0264-header.jpg',
#   'image_name': 'N193-031_0264-header.jpg',
#   'volume': 'N193-031',
#   'volume_number': 31,
#   'page_number': 264},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-064_0199-header.jpg',
#   'image_name': 'N193-064_0199-header.jpg',
#   'volume': 'N193-064',
#   'volume_number': 64,
#   'page_number': 199},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-158_0244-header.jpg',
#   'image_name': 'N193-158_0244-header.jpg',
#   'volume': 'N193-158',
#   'volume_number': 158,
#   'page_number': 244},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-110_0262-header.jpg',
#   'image_name': 'N193-110_0262-header.jpg',
#   'volume': 'N193-110',
#   'volume_number': 110,
#   'page_number': 262},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-152_0364-header.jpg',
#   'image_name': 'N193-152_0364-header.jpg',
#   'volume': 'N193-152',
#   'volume_number': 152,
#   'page_number': 364},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-170_0236-header.jpg',
#   'image_name': 'N193-170_0236-header.jpg',
#   'volume': 'N193-170',
#   'volume_number': 170,
#   'page_number': 236},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-032_0110-header.jpg',
#   'image_name': 'N193-032_0110-header.jpg',
#   'volume': 'N193-032',
#   'volume_number': 32,
#   'page_number': 110},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-041_0087-header.jpg',
#   'image_name': 'N193-041_0087-header.jpg',
#   'volume': 'N193-041',
#   'volume_number': 41,
#   'page_number': 87},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-001_0056-header.jpg',
#   'image_name': 'N193-001_0056-header.jpg',
#   'volume': 'N193-001',
#   'volume_number': 1,
#   'page_number': 56},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-070_0016-header.jpg',
#   'image_name': 'N193-070_0016-header.jpg',
#   'volume': 'N193-070',
#   'volume_number': 70,
#   'page_number': 16},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-188_0116-header.jpg',
#   'image_name': 'N193-188_0116-header.jpg',
#   'volume': 'N193-188',
#   'volume_number': 188,
#   'page_number': 116},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-019_0302-header.jpg',
#   'image_name': 'N193-019_0302-header.jpg',
#   'volume': 'N193-019',
#   'volume_number': 19,
#   'page_number': 302},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-029_0024-header.jpg',
#   'image_name': 'N193-029_0024-header.jpg',
#   'volume': 'N193-029',
#   'volume_number': 29,
#   'page_number': 24},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-120_0111-header.jpg',
#   'image_name': 'N193-120_0111-header.jpg',
#   'volume': 'N193-120',
#   'volume_number': 120,
#   'page_number': 111},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-117_0112-header.jpg',
#   'image_name': 'N193-117_0112-header.jpg',
#   'volume': 'N193-117',
#   'volume_number': 117,
#   'page_number': 112},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-177_0171-header.jpg',
#   'image_name': 'N193-177_0171-header.jpg',
#   'volume': 'N193-177',
#   'volume_number': 177,
#   'page_number': 171},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-147_0416-header.jpg',
#   'image_name': 'N193-147_0416-header.jpg',
#   'volume': 'N193-147',
#   'volume_number': 147,
#   'page_number': 416},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-196_0285-header.jpg',
#   'image_name': 'N193-196_0285-header.jpg',
#   'volume': 'N193-196',
#   'volume_number': 196,
#   'page_number': 285},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-154_0280-header.jpg',
#   'image_name': 'N193-154_0280-header.jpg',
#   'volume': 'N193-154',
#   'volume_number': 154,
#   'page_number': 280},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-173_0120-header.jpg',
#   'image_name': 'N193-173_0120-header.jpg',
#   'volume': 'N193-173',
#   'volume_number': 173,
#   'page_number': 120},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-117_0031-header.jpg',
#   'image_name': 'N193-117_0031-header.jpg',
#   'volume': 'N193-117',
#   'volume_number': 117,
#   'page_number': 31},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-147_0352-header.jpg',
#   'image_name': 'N193-147_0352-header.jpg',
#   'volume': 'N193-147',
#   'volume_number': 147,
#   'page_number': 352},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-188_0165-header.jpg',
#   'image_name': 'N193-188_0165-header.jpg',
#   'volume': 'N193-188',
#   'volume_number': 188,
#   'page_number': 165},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-149_0300-header.jpg',
#   'image_name': 'N193-149_0300-header.jpg',
#   'volume': 'N193-149',
#   'volume_number': 149,
#   'page_number': 300},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-191_0186-header.jpg',
#   'image_name': 'N193-191_0186-header.jpg',
#   'volume': 'N193-191',
#   'volume_number': 191,
#   'page_number': 186},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-166_0057-header.jpg',
#   'image_name': 'N193-166_0057-header.jpg',
#   'volume': 'N193-166',
#   'volume_number': 166,
#   'page_number': 57},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-150_0481-header.jpg',
#   'image_name': 'N193-150_0481-header.jpg',
#   'volume': 'N193-150',
#   'volume_number': 150,
#   'page_number': 481},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-056_0072-header.jpg',
#   'image_name': 'N193-056_0072-header.jpg',
#   'volume': 'N193-056',
#   'volume_number': 56,
#   'page_number': 72},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-168_0278-header.jpg',
#   'image_name': 'N193-168_0278-header.jpg',
#   'volume': 'N193-168',
#   'volume_number': 168,
#   'page_number': 278},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-058_0020-header.jpg',
#   'image_name': 'N193-058_0020-header.jpg',
#   'volume': 'N193-058',
#   'volume_number': 58,
#   'page_number': 20},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-017_0237-header.jpg',
#   'image_name': 'N193-017_0237-header.jpg',
#   'volume': 'N193-017',
#   'volume_number': 17,
#   'page_number': 237},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-001_0106-header.jpg',
#   'image_name': 'N193-001_0106-header.jpg',
#   'volume': 'N193-001',
#   'volume_number': 1,
#   'page_number': 106},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-019_0018-header.jpg',
#   'image_name': 'N193-019_0018-header.jpg',
#   'volume': 'N193-019',
#   'volume_number': 19,
#   'page_number': 18},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-059_0283-header.jpg',
#   'image_name': 'N193-059_0283-header.jpg',
#   'volume': 'N193-059',
#   'volume_number': 59,
#   'page_number': 283},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-070_0171-header.jpg',
#   'image_name': 'N193-070_0171-header.jpg',
#   'volume': 'N193-070',
#   'volume_number': 70,
#   'page_number': 171},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-122_0196-header.jpg',
#   'image_name': 'N193-122_0196-header.jpg',
#   'volume': 'N193-122',
#   'volume_number': 122,
#   'page_number': 196},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-062_0244-header.jpg',
#   'image_name': 'N193-062_0244-header.jpg',
#   'volume': 'N193-062',
#   'volume_number': 62,
#   'page_number': 244},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-152_0534-header.jpg',
#   'image_name': 'N193-152_0534-header.jpg',
#   'volume': 'N193-152',
#   'volume_number': 152,
#   'page_number': 534},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-132_0202-header.jpg',
#   'image_name': 'N193-132_0202-header.jpg',
#   'volume': 'N193-132',
#   'volume_number': 132,
#   'page_number': 202},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-038_0016-header.jpg',
#   'image_name': 'N193-038_0016-header.jpg',
#   'volume': 'N193-038',
#   'volume_number': 38,
#   'page_number': 16},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-092_0087-header.jpg',
#   'image_name': 'N193-092_0087-header.jpg',
#   'volume': 'N193-092',
#   'volume_number': 92,
#   'page_number': 87},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-124_0010-header.jpg',
#   'image_name': 'N193-124_0010-header.jpg',
#   'volume': 'N193-124',
#   'volume_number': 124,
#   'page_number': 10},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-193_0438-header.jpg',
#   'image_name': 'N193-193_0438-header.jpg',
#   'volume': 'N193-193',
#   'volume_number': 193,
#   'page_number': 438},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-043_0228-header.jpg',
#   'image_name': 'N193-043_0228-header.jpg',
#   'volume': 'N193-043',
#   'volume_number': 43,
#   'page_number': 228},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-113_0024-header.jpg',
#   'image_name': 'N193-113_0024-header.jpg',
#   'volume': 'N193-113',
#   'volume_number': 113,
#   'page_number': 24},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-056_0104-header.jpg',
#   'image_name': 'N193-056_0104-header.jpg',
#   'volume': 'N193-056',
#   'volume_number': 56,
#   'page_number': 104},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-029_0116-header.jpg',
#   'image_name': 'N193-029_0116-header.jpg',
#   'volume': 'N193-029',
#   'volume_number': 29,
#   'page_number': 116},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-183_0006-header.jpg',
#   'image_name': 'N193-183_0006-header.jpg',
#   'volume': 'N193-183',
#   'volume_number': 183,
#   'page_number': 6},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-163_0151-header.jpg',
#   'image_name': 'N193-163_0151-header.jpg',
#   'volume': 'N193-163',
#   'volume_number': 163,
#   'page_number': 151},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-141_0003-header.jpg',
#   'image_name': 'N193-141_0003-header.jpg',
#   'volume': 'N193-141',
#   'volume_number': 141,
#   'page_number': 3},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-034_0205-header.jpg',
#   'image_name': 'N193-034_0205-header.jpg',
#   'volume': 'N193-034',
#   'volume_number': 34,
#   'page_number': 205},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-163_0633-header.jpg',
#   'image_name': 'N193-163_0633-header.jpg',
#   'volume': 'N193-163',
#   'volume_number': 163,
#   'page_number': 633},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-188_0291-header.jpg',
#   'image_name': 'N193-188_0291-header.jpg',
#   'volume': 'N193-188',
#   'volume_number': 188,
#   'page_number': 291},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-072_0271-header.jpg',
#   'image_name': 'N193-072_0271-header.jpg',
#   'volume': 'N193-072',
#   'volume_number': 72,
#   'page_number': 271},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-059_0054-header.jpg',
#   'image_name': 'N193-059_0054-header.jpg',
#   'volume': 'N193-059',
#   'volume_number': 59,
#   'page_number': 54},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-198_0132-header.jpg',
#   'image_name': 'N193-198_0132-header.jpg',
#   'volume': 'N193-198',
#   'volume_number': 198,
#   'page_number': 132},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-187_0057-header.jpg',
#   'image_name': 'N193-187_0057-header.jpg',
#   'volume': 'N193-187',
#   'volume_number': 187,
#   'page_number': 57},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-160_0225-header.jpg',
#   'image_name': 'N193-160_0225-header.jpg',
#   'volume': 'N193-160',
#   'volume_number': 160,
#   'page_number': 225},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-153_0401-header.jpg',
#   'image_name': 'N193-153_0401-header.jpg',
#   'volume': 'N193-153',
#   'volume_number': 153,
#   'page_number': 401},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-198_0011-header.jpg',
#   'image_name': 'N193-198_0011-header.jpg',
#   'volume': 'N193-198',
#   'volume_number': 198,
#   'page_number': 11},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-142_0201-header.jpg',
#   'image_name': 'N193-142_0201-header.jpg',
#   'volume': 'N193-142',
#   'volume_number': 142,
#   'page_number': 201},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-011_0027-header.jpg',
#   'image_name': 'N193-011_0027-header.jpg',
#   'volume': 'N193-011',
#   'volume_number': 11,
#   'page_number': 27},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-189_0339-header.jpg',
#   'image_name': 'N193-189_0339-header.jpg',
#   'volume': 'N193-189',
#   'volume_number': 189,
#   'page_number': 339},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-115_0261-header.jpg',
#   'image_name': 'N193-115_0261-header.jpg',
#   'volume': 'N193-115',
#   'volume_number': 115,
#   'page_number': 261},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-155_0393-header.jpg',
#   'image_name': 'N193-155_0393-header.jpg',
#   'volume': 'N193-155',
#   'volume_number': 155,
#   'page_number': 393},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-173_0384-header.jpg',
#   'image_name': 'N193-173_0384-header.jpg',
#   'volume': 'N193-173',
#   'volume_number': 173,
#   'page_number': 384},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-116_0115-header.jpg',
#   'image_name': 'N193-116_0115-header.jpg',
#   'volume': 'N193-116',
#   'volume_number': 116,
#   'page_number': 115},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-061_0304-header.jpg',
#   'image_name': 'N193-061_0304-header.jpg',
#   'volume': 'N193-061',
#   'volume_number': 61,
#   'page_number': 304},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-190_0339-header.jpg',
#   'image_name': 'N193-190_0339-header.jpg',
#   'volume': 'N193-190',
#   'volume_number': 190,
#   'page_number': 339},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-110_0047-header.jpg',
#   'image_name': 'N193-110_0047-header.jpg',
#   'volume': 'N193-110',
#   'volume_number': 110,
#   'page_number': 47},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-040_0122-header.jpg',
#   'image_name': 'N193-040_0122-header.jpg',
#   'volume': 'N193-040',
#   'volume_number': 40,
#   'page_number': 122},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-061_0210-header.jpg',
#   'image_name': 'N193-061_0210-header.jpg',
#   'volume': 'N193-061',
#   'volume_number': 61,
#   'page_number': 210},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-105_0002-header.jpg',
#   'image_name': 'N193-105_0002-header.jpg',
#   'volume': 'N193-105',
#   'volume_number': 105,
#   'page_number': 2},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-166_0201-header.jpg',
#   'image_name': 'N193-166_0201-header.jpg',
#   'volume': 'N193-166',
#   'volume_number': 166,
#   'page_number': 201},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-058_0276-header.jpg',
#   'image_name': 'N193-058_0276-header.jpg',
#   'volume': 'N193-058',
#   'volume_number': 58,
#   'page_number': 276},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-079_0005-header.jpg',
#   'image_name': 'N193-079_0005-header.jpg',
#   'volume': 'N193-079',
#   'volume_number': 79,
#   'page_number': 5},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-151_0343-header.jpg',
#   'image_name': 'N193-151_0343-header.jpg',
#   'volume': 'N193-151',
#   'volume_number': 151,
#   'page_number': 343},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-149_0508-header.jpg',
#   'image_name': 'N193-149_0508-header.jpg',
#   'volume': 'N193-149',
#   'volume_number': 149,
#   'page_number': 508},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-057_0298-header.jpg',
#   'image_name': 'N193-057_0298-header.jpg',
#   'volume': 'N193-057',
#   'volume_number': 57,
#   'page_number': 298},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-096_0280-header.jpg',
#   'image_name': 'N193-096_0280-header.jpg',
#   'volume': 'N193-096',
#   'volume_number': 96,
#   'page_number': 280},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-091_0086-header.jpg',
#   'image_name': 'N193-091_0086-header.jpg',
#   'volume': 'N193-091',
#   'volume_number': 91,
#   'page_number': 86},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-162_0473-header.jpg',
#   'image_name': 'N193-162_0473-header.jpg',
#   'volume': 'N193-162',
#   'volume_number': 162,
#   'page_number': 473},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-075_0094-header.jpg',
#   'image_name': 'N193-075_0094-header.jpg',
#   'volume': 'N193-075',
#   'volume_number': 75,
#   'page_number': 94},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-159_0297-header.jpg',
#   'image_name': 'N193-159_0297-header.jpg',
#   'volume': 'N193-159',
#   'volume_number': 159,
#   'page_number': 297},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-055_0011-header.jpg',
#   'image_name': 'N193-055_0011-header.jpg',
#   'volume': 'N193-055',
#   'volume_number': 55,
#   'page_number': 11},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-110_0106-header.jpg',
#   'image_name': 'N193-110_0106-header.jpg',
#   'volume': 'N193-110',
#   'volume_number': 110,
#   'page_number': 106},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-043_0317-header.jpg',
#   'image_name': 'N193-043_0317-header.jpg',
#   'volume': 'N193-043',
#   'volume_number': 43,
#   'page_number': 317},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-173_0332-header.jpg',
#   'image_name': 'N193-173_0332-header.jpg',
#   'volume': 'N193-173',
#   'volume_number': 173,
#   'page_number': 332},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-187_0201-header.jpg',
#   'image_name': 'N193-187_0201-header.jpg',
#   'volume': 'N193-187',
#   'volume_number': 187,
#   'page_number': 201},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-153_0135-header.jpg',
#   'image_name': 'N193-153_0135-header.jpg',
#   'volume': 'N193-153',
#   'volume_number': 153,
#   'page_number': 135},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-091_0233-header.jpg',
#   'image_name': 'N193-091_0233-header.jpg',
#   'volume': 'N193-091',
#   'volume_number': 91,
#   'page_number': 233},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-033_0262-header.jpg',
#   'image_name': 'N193-033_0262-header.jpg',
#   'volume': 'N193-033',
#   'volume_number': 33,
#   'page_number': 262},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-160_0239-header.jpg',
#   'image_name': 'N193-160_0239-header.jpg',
#   'volume': 'N193-160',
#   'volume_number': 160,
#   'page_number': 239},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-100_0133-header.jpg',
#   'image_name': 'N193-100_0133-header.jpg',
#   'volume': 'N193-100',
#   'volume_number': 100,
#   'page_number': 133},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-154_0451-header.jpg',
#   'image_name': 'N193-154_0451-header.jpg',
#   'volume': 'N193-154',
#   'volume_number': 154,
#   'page_number': 451},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-0039_0163-header.jpg',
#   'image_name': 'N193-0039_0163-header.jpg',
#   'volume': 'N193-0039',
#   'volume_number': 39,
#   'page_number': 163},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-104_0041-header.jpg',
#   'image_name': 'N193-104_0041-header.jpg',
#   'volume': 'N193-104',
#   'volume_number': 104,
#   'page_number': 41},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-162_0087-header.jpg',
#   'image_name': 'N193-162_0087-header.jpg',
#   'volume': 'N193-162',
#   'volume_number': 162,
#   'page_number': 87},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-159_0040-header.jpg',
#   'image_name': 'N193-159_0040-header.jpg',
#   'volume': 'N193-159',
#   'volume_number': 159,
#   'page_number': 40},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-180_0146-header.jpg',
#   'image_name': 'N193-180_0146-header.jpg',
#   'volume': 'N193-180',
#   'volume_number': 180,
#   'page_number': 146},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-132_0283-header.jpg',
#   'image_name': 'N193-132_0283-header.jpg',
#   'volume': 'N193-132',
#   'volume_number': 132,
#   'page_number': 283},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-122_0003-header.jpg',
#   'image_name': 'N193-122_0003-header.jpg',
#   'volume': 'N193-122',
#   'volume_number': 122,
#   'page_number': 3},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-175_0054-header.jpg',
#   'image_name': 'N193-175_0054-header.jpg',
#   'volume': 'N193-175',
#   'volume_number': 175,
#   'page_number': 54},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-028_0217-header.jpg',
#   'image_name': 'N193-028_0217-header.jpg',
#   'volume': 'N193-028',
#   'volume_number': 28,
#   'page_number': 217},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-128_0123-header.jpg',
#   'image_name': 'N193-128_0123-header.jpg',
#   'volume': 'N193-128',
#   'volume_number': 128,
#   'page_number': 123},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-175_0063-header.jpg',
#   'image_name': 'N193-175_0063-header.jpg',
#   'volume': 'N193-175',
#   'volume_number': 175,
#   'page_number': 63},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-084_0223-header.jpg',
#   'image_name': 'N193-084_0223-header.jpg',
#   'volume': 'N193-084',
#   'volume_number': 84,
#   'page_number': 223},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-036_0089-header.jpg',
#   'image_name': 'N193-036_0089-header.jpg',
#   'volume': 'N193-036',
#   'volume_number': 36,
#   'page_number': 89},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-121_0171-header.jpg',
#   'image_name': 'N193-121_0171-header.jpg',
#   'volume': 'N193-121',
#   'volume_number': 121,
#   'page_number': 171},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-091_0057-header.jpg',
#   'image_name': 'N193-091_0057-header.jpg',
#   'volume': 'N193-091',
#   'volume_number': 91,
#   'page_number': 57},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-116_0172-header.jpg',
#   'image_name': 'N193-116_0172-header.jpg',
#   'volume': 'N193-116',
#   'volume_number': 116,
#   'page_number': 172},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-147_0180-header.jpg',
#   'image_name': 'N193-147_0180-header.jpg',
#   'volume': 'N193-147',
#   'volume_number': 147,
#   'page_number': 180},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-067_0206-header.jpg',
#   'image_name': 'N193-067_0206-header.jpg',
#   'volume': 'N193-067',
#   'volume_number': 67,
#   'page_number': 206},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-128_0231-header.jpg',
#   'image_name': 'N193-128_0231-header.jpg',
#   'volume': 'N193-128',
#   'volume_number': 128,
#   'page_number': 231},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-130_0152-header.jpg',
#   'image_name': 'N193-130_0152-header.jpg',
#   'volume': 'N193-130',
#   'volume_number': 130,
#   'page_number': 152},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-104_0212-header.jpg',
#   'image_name': 'N193-104_0212-header.jpg',
#   'volume': 'N193-104',
#   'volume_number': 104,
#   'page_number': 212},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-160_0334-header.jpg',
#   'image_name': 'N193-160_0334-header.jpg',
#   'volume': 'N193-160',
#   'volume_number': 160,
#   'page_number': 334},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-146_0441-header.jpg',
#   'image_name': 'N193-146_0441-header.jpg',
#   'volume': 'N193-146',
#   'volume_number': 146,
#   'page_number': 441},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-034_0200-header.jpg',
#   'image_name': 'N193-034_0200-header.jpg',
#   'volume': 'N193-034',
#   'volume_number': 34,
#   'page_number': 200},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-025_0128-header.jpg',
#   'image_name': 'N193-025_0128-header.jpg',
#   'volume': 'N193-025',
#   'volume_number': 25,
#   'page_number': 128},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-192_0449-header.jpg',
#   'image_name': 'N193-192_0449-header.jpg',
#   'volume': 'N193-192',
#   'volume_number': 192,
#   'page_number': 449},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-126_0236-header.jpg',
#   'image_name': 'N193-126_0236-header.jpg',
#   'volume': 'N193-126',
#   'volume_number': 126,
#   'page_number': 236},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-127_0181-header.jpg',
#   'image_name': 'N193-127_0181-header.jpg',
#   'volume': 'N193-127',
#   'volume_number': 127,
#   'page_number': 181},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-041_0273-header.jpg',
#   'image_name': 'N193-041_0273-header.jpg',
#   'volume': 'N193-041',
#   'volume_number': 41,
#   'page_number': 273},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-086_0190-header.jpg',
#   'image_name': 'N193-086_0190-header.jpg',
#   'volume': 'N193-086',
#   'volume_number': 86,
#   'page_number': 190},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-167_0073-header.jpg',
#   'image_name': 'N193-167_0073-header.jpg',
#   'volume': 'N193-167',
#   'volume_number': 167,
#   'page_number': 73},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-059_0286-header.jpg',
#   'image_name': 'N193-059_0286-header.jpg',
#   'volume': 'N193-059',
#   'volume_number': 59,
#   'page_number': 286},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-156_0502-header.jpg',
#   'image_name': 'N193-156_0502-header.jpg',
#   'volume': 'N193-156',
#   'volume_number': 156,
#   'page_number': 502},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-024_0109-header.jpg',
#   'image_name': 'N193-024_0109-header.jpg',
#   'volume': 'N193-024',
#   'volume_number': 24,
#   'page_number': 109},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-173_0020-header.jpg',
#   'image_name': 'N193-173_0020-header.jpg',
#   'volume': 'N193-173',
#   'volume_number': 173,
#   'page_number': 20},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-124_0077-header.jpg',
#   'image_name': 'N193-124_0077-header.jpg',
#   'volume': 'N193-124',
#   'volume_number': 124,
#   'page_number': 77},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-156_0374-header.jpg',
#   'image_name': 'N193-156_0374-header.jpg',
#   'volume': 'N193-156',
#   'volume_number': 156,
#   'page_number': 374},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-136_0317-header.jpg',
#   'image_name': 'N193-136_0317-header.jpg',
#   'volume': 'N193-136',
#   'volume_number': 136,
#   'page_number': 317},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-193_0063-header.jpg',
#   'image_name': 'N193-193_0063-header.jpg',
#   'volume': 'N193-193',
#   'volume_number': 193,
#   'page_number': 63},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-081_0228-header.jpg',
#   'image_name': 'N193-081_0228-header.jpg',
#   'volume': 'N193-081',
#   'volume_number': 81,
#   'page_number': 228},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-041_0187-header.jpg',
#   'image_name': 'N193-041_0187-header.jpg',
#   'volume': 'N193-041',
#   'volume_number': 41,
#   'page_number': 187},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-106_0170-header.jpg',
#   'image_name': 'N193-106_0170-header.jpg',
#   'volume': 'N193-106',
#   'volume_number': 106,
#   'page_number': 170},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-110_0241-header.jpg',
#   'image_name': 'N193-110_0241-header.jpg',
#   'volume': 'N193-110',
#   'volume_number': 110,
#   'page_number': 241},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-020_0019-header.jpg',
#   'image_name': 'N193-020_0019-header.jpg',
#   'volume': 'N193-020',
#   'volume_number': 20,
#   'page_number': 19},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-129_0227-header.jpg',
#   'image_name': 'N193-129_0227-header.jpg',
#   'volume': 'N193-129',
#   'volume_number': 129,
#   'page_number': 227},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-185_0224-header.jpg',
#   'image_name': 'N193-185_0224-header.jpg',
#   'volume': 'N193-185',
#   'volume_number': 185,
# ...
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-167_0136-header.jpg',
#   'image_name': 'N193-167_0136-header.jpg',
#   'volume': 'N193-167',
#   'volume_number': 167,
#   'page_number': 136},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-130_0161-header.jpg',
#   'image_name': 'N193-130_0161-header.jpg',
#   'volume': 'N193-130',
#   'volume_number': 130,
#   'page_number': 161},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-059_0141-header.jpg',
#   'image_name': 'N193-059_0141-header.jpg',
#   'volume': 'N193-059',
#   'volume_number': 59,
#   'page_number': 141},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-011_0011-header.jpg',
#   'image_name': 'N193-011_0011-header.jpg',
#   'volume': 'N193-011',
#   'volume_number': 11,
#   'page_number': 11},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-048_0269-header.jpg',
#   'image_name': 'N193-048_0269-header.jpg',
#   'volume': 'N193-048',
#   'volume_number': 48,
#   'page_number': 269},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-195_0129-header.jpg',
#   'image_name': 'N193-195_0129-header.jpg',
#   'volume': 'N193-195',
#   'volume_number': 195,
#   'page_number': 129},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-159_0149-header.jpg',
#   'image_name': 'N193-159_0149-header.jpg',
#   'volume': 'N193-159',
#   'volume_number': 159,
#   'page_number': 149},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-134_0152-header.jpg',
#   'image_name': 'N193-134_0152-header.jpg',
#   'volume': 'N193-134',
#   'volume_number': 134,
#   'page_number': 152},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-022_0043-header.jpg',
#   'image_name': 'N193-022_0043-header.jpg',
#   'volume': 'N193-022',
#   'volume_number': 22,
#   'page_number': 43},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-111_0206-header.jpg',
#   'image_name': 'N193-111_0206-header.jpg',
#   'volume': 'N193-111',
#   'volume_number': 111,
#   'page_number': 206},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-142_0314-header.jpg',
#   'image_name': 'N193-142_0314-header.jpg',
#   'volume': 'N193-142',
#   'volume_number': 142,
#   'page_number': 314},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-042_0020-header.jpg',
#   'image_name': 'N193-042_0020-header.jpg',
#   'volume': 'N193-042',
#   'volume_number': 42,
#   'page_number': 20},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-160_0271-header.jpg',
#   'image_name': 'N193-160_0271-header.jpg',
#   'volume': 'N193-160',
#   'volume_number': 160,
#   'page_number': 271},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-169_0106-header.jpg',
#   'image_name': 'N193-169_0106-header.jpg',
#   'volume': 'N193-169',
#   'volume_number': 169,
#   'page_number': 106},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-056_0239-header.jpg',
#   'image_name': 'N193-056_0239-header.jpg',
#   'volume': 'N193-056',
#   'volume_number': 56,
#   'page_number': 239},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-145_0284-header.jpg',
#   'image_name': 'N193-145_0284-header.jpg',
#   'volume': 'N193-145',
#   'volume_number': 145,
#   'page_number': 284},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-161_0139-header.jpg',
#   'image_name': 'N193-161_0139-header.jpg',
#   'volume': 'N193-161',
#   'volume_number': 161,
#   'page_number': 139},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-154_0290-header.jpg',
#   'image_name': 'N193-154_0290-header.jpg',
#   'volume': 'N193-154',
#   'volume_number': 154,
#   'page_number': 290},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-181_0224-header.jpg',
#   'image_name': 'N193-181_0224-header.jpg',
#   'volume': 'N193-181',
#   'volume_number': 181,
#   'page_number': 224},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-002_0039-header.jpg',
#   'image_name': 'N193-002_0039-header.jpg',
#   'volume': 'N193-002',
#   'volume_number': 2,
#   'page_number': 39},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-005_0161-header.jpg',
#   'image_name': 'N193-005_0161-header.jpg',
#   'volume': 'N193-005',
#   'volume_number': 5,
#   'page_number': 161},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-147_0525-header.jpg',
#   'image_name': 'N193-147_0525-header.jpg',
#   'volume': 'N193-147',
#   'volume_number': 147,
#   'page_number': 525},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-058_0102-header.jpg',
#   'image_name': 'N193-058_0102-header.jpg',
#   'volume': 'N193-058',
#   'volume_number': 58,
#   'page_number': 102},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-162_0030-header.jpg',
#   'image_name': 'N193-162_0030-header.jpg',
#   'volume': 'N193-162',
#   'volume_number': 162,
#   'page_number': 30},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-081_0279-header.jpg',
#   'image_name': 'N193-081_0279-header.jpg',
#   'volume': 'N193-081',
#   'volume_number': 81,
#   'page_number': 279},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-074_0248-header.jpg',
#   'image_name': 'N193-074_0248-header.jpg',
#   'volume': 'N193-074',
#   'volume_number': 74,
#   'page_number': 248},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-190_0159-header.jpg',
#   'image_name': 'N193-190_0159-header.jpg',
#   'volume': 'N193-190',
#   'volume_number': 190,
#   'page_number': 159},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-131_0229-header.jpg',
#   'image_name': 'N193-131_0229-header.jpg',
#   'volume': 'N193-131',
#   'volume_number': 131,
#   'page_number': 229},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-051_0303-header.jpg',
#   'image_name': 'N193-051_0303-header.jpg',
#   'volume': 'N193-051',
#   'volume_number': 51,
#   'page_number': 303},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-156_0447-header.jpg',
#   'image_name': 'N193-156_0447-header.jpg',
#   'volume': 'N193-156',
#   'volume_number': 156,
#   'page_number': 447},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-108_0278-header.jpg',
#   'image_name': 'N193-108_0278-header.jpg',
#   'volume': 'N193-108',
#   'volume_number': 108,
#   'page_number': 278},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-006_0129-header.jpg',
#   'image_name': 'N193-006_0129-header.jpg',
#   'volume': 'N193-006',
#   'volume_number': 6,
#   'page_number': 129},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-170_0332-header.jpg',
#   'image_name': 'N193-170_0332-header.jpg',
#   'volume': 'N193-170',
#   'volume_number': 170,
#   'page_number': 332},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-162_0171-header.jpg',
#   'image_name': 'N193-162_0171-header.jpg',
#   'volume': 'N193-162',
#   'volume_number': 162,
#   'page_number': 171},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-174_0240-header.jpg',
#   'image_name': 'N193-174_0240-header.jpg',
#   'volume': 'N193-174',
#   'volume_number': 174,
#   'page_number': 240},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-001_0165-header.jpg',
#   'image_name': 'N193-001_0165-header.jpg',
#   'volume': 'N193-001',
#   'volume_number': 1,
#   'page_number': 165},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-054_0298-header.jpg',
#   'image_name': 'N193-054_0298-header.jpg',
#   'volume': 'N193-054',
#   'volume_number': 54,
#   'page_number': 298},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-127_0271-header.jpg',
#   'image_name': 'N193-127_0271-header.jpg',
#   'volume': 'N193-127',
#   'volume_number': 127,
#   'page_number': 271},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-127_0246-header.jpg',
#   'image_name': 'N193-127_0246-header.jpg',
#   'volume': 'N193-127',
#   'volume_number': 127,
#   'page_number': 246},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-158_0254-header.jpg',
#   'image_name': 'N193-158_0254-header.jpg',
#   'volume': 'N193-158',
#   'volume_number': 158,
#   'page_number': 254},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-167_0297-header.jpg',
#   'image_name': 'N193-167_0297-header.jpg',
#   'volume': 'N193-167',
#   'volume_number': 167,
#   'page_number': 297},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-090_0185-header.jpg',
#   'image_name': 'N193-090_0185-header.jpg',
#   'volume': 'N193-090',
#   'volume_number': 90,
#   'page_number': 185},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-163_0058-header.jpg',
#   'image_name': 'N193-163_0058-header.jpg',
#   'volume': 'N193-163',
#   'volume_number': 163,
#   'page_number': 58},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-009_0218-header.jpg',
#   'image_name': 'N193-009_0218-header.jpg',
#   'volume': 'N193-009',
#   'volume_number': 9,
#   'page_number': 218},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-045_0131-header.jpg',
#   'image_name': 'N193-045_0131-header.jpg',
#   'volume': 'N193-045',
#   'volume_number': 45,
#   'page_number': 131},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-192_0404-header.jpg',
#   'image_name': 'N193-192_0404-header.jpg',
#   'volume': 'N193-192',
#   'volume_number': 192,
#   'page_number': 404},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-126_0006-header.jpg',
#   'image_name': 'N193-126_0006-header.jpg',
#   'volume': 'N193-126',
#   'volume_number': 126,
#   'page_number': 6},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-137_0131-header.jpg',
#   'image_name': 'N193-137_0131-header.jpg',
#   'volume': 'N193-137',
#   'volume_number': 137,
#   'page_number': 131},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-028_0009-header.jpg',
#   'image_name': 'N193-028_0009-header.jpg',
#   'volume': 'N193-028',
#   'volume_number': 28,
#   'page_number': 9},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-065_0097-header.jpg',
#   'image_name': 'N193-065_0097-header.jpg',
#   'volume': 'N193-065',
#   'volume_number': 65,
#   'page_number': 97},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-142_0003-header.jpg',
#   'image_name': 'N193-142_0003-header.jpg',
#   'volume': 'N193-142',
#   'volume_number': 142,
#   'page_number': 3},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-059_0203-header.jpg',
#   'image_name': 'N193-059_0203-header.jpg',
#   'volume': 'N193-059',
#   'volume_number': 59,
#   'page_number': 203},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-003_0066-header.jpg',
#   'image_name': 'N193-003_0066-header.jpg',
#   'volume': 'N193-003',
#   'volume_number': 3,
#   'page_number': 66},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-028_0302-header.jpg',
#   'image_name': 'N193-028_0302-header.jpg',
#   'volume': 'N193-028',
#   'volume_number': 28,
#   'page_number': 302},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-159_0569-header.jpg',
#   'image_name': 'N193-159_0569-header.jpg',
#   'volume': 'N193-159',
#   'volume_number': 159,
#   'page_number': 569},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-032_0181-header.jpg',
#   'image_name': 'N193-032_0181-header.jpg',
#   'volume': 'N193-032',
#   'volume_number': 32,
#   'page_number': 181},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-091_0267-header.jpg',
#   'image_name': 'N193-091_0267-header.jpg',
#   'volume': 'N193-091',
#   'volume_number': 91,
#   'page_number': 267},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-089_0104-header.jpg',
#   'image_name': 'N193-089_0104-header.jpg',
#   'volume': 'N193-089',
#   'volume_number': 89,
#   'page_number': 104},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-023_0195-header.jpg',
#   'image_name': 'N193-023_0195-header.jpg',
#   'volume': 'N193-023',
#   'volume_number': 23,
#   'page_number': 195},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-007_0176-header.jpg',
#   'image_name': 'N193-007_0176-header.jpg',
#   'volume': 'N193-007',
#   'volume_number': 7,
#   'page_number': 176},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-054_0064-header.jpg',
#   'image_name': 'N193-054_0064-header.jpg',
#   'volume': 'N193-054',
#   'volume_number': 54,
#   'page_number': 64},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-041_0135-header.jpg',
#   'image_name': 'N193-041_0135-header.jpg',
#   'volume': 'N193-041',
#   'volume_number': 41,
#   'page_number': 135},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-025_0013-header.jpg',
#   'image_name': 'N193-025_0013-header.jpg',
#   'volume': 'N193-025',
#   'volume_number': 25,
#   'page_number': 13},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-026_0273-header.jpg',
#   'image_name': 'N193-026_0273-header.jpg',
#   'volume': 'N193-026',
#   'volume_number': 26,
#   'page_number': 273},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-056_0184-header.jpg',
#   'image_name': 'N193-056_0184-header.jpg',
#   'volume': 'N193-056',
#   'volume_number': 56,
#   'page_number': 184},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-072_0239-header.jpg',
#   'image_name': 'N193-072_0239-header.jpg',
#   'volume': 'N193-072',
#   'volume_number': 72,
#   'page_number': 239},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-133_0021-header.jpg',
#   'image_name': 'N193-133_0021-header.jpg',
#   'volume': 'N193-133',
#   'volume_number': 133,
#   'page_number': 21},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/samples/headers/N193-029_0314-header.jpg',
#   'image_name': 'N193-029_0314-header.jpg',
#   'volume': 'N193-029',
#   'volume_number': 29,
#   'page_number': 314},
#  ...]

# %% [markdown]
# Loop through the metadata creating new Zooniverse subjects. The images are resized before they are added to the subjects.

# %%
new_subjects = []
for item in data:
    # New Zooniverse subject
    subject = Subject()
    
    # Link subject to project
    subject.links.project = project
    
    # Open the image
    img = Image.open(item['image_path'])
    w, h = img.size
    
    # Get the resize ratio based on a maximum width of 2000 px
    ratio = 2000 / w
    
    # Resize image using the ratio
    img = img.resize((int(w*ratio), int(h*ratio)), Image.LANCZOS)
    
    # Create a bytes object and save the image to it
    b = io.BytesIO()
    img.save(b, 'JPEG')
    b.seek(0)
    
    # Add the bytes object to the subject
    subject.add_location(b)
    
    # Add metadata to the subject
    subject.metadata['image'] = item['image_name']
    subject.metadata['volume'] = item['volume']
    subject.metadata['volume_number'] = item['volume_number']
    subject.metadata['page_number'] = item['page_number']
    subject.metadata['year'] = 1930
    
    # Save the subject
    subject.save()
    
    # Add to the list of subjects
    new_subjects.append(subject)

# %%
# Save the list of subjects to the subject set
subject_set.add(new_subjects)
