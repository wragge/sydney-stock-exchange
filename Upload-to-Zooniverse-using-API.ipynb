# %% [markdown]
# # Upload subject sets to Zooniverse using the Panoptes client

# %% [markdown]
# See the [Panoptes-client documentation](https://panoptes-python-client.readthedocs.io/en/v1.1/index.html#).

# %%
import os
import glob
import re
import io
from PIL import Image
from panoptes_client import Panoptes, Project, SubjectSet, Subject
from credentials import ZOONIVERSE_USER, ZOONIVERSE_PW

# %%
Panoptes.connect(username=ZOONIVERSE_USER, password=ZOONIVERSE_PW)

# %%
project = Project.find('8678')
project.title
# Out:
# 'Sydney Stock Exchange'

# %% [markdown]
# ## Create a new subject set

# %%
# New subject set
subject_set = SubjectSet()

subject_set.links.project = project
subject_set.display_name = '1929 headers test'

subject_set.save()
# Out:
# {'subject_sets': [{'id': '76904',
#    'display_name': '1929 headers test',
#    'set_member_subjects_count': 0,
#    'metadata': {},
#    'created_at': '2019-07-17T04:44:39.170Z',
#    'updated_at': '2019-07-17T04:44:39.170Z',
#    'href': '/subject_sets/76904',
#    'links': {'project': '8678', 'workflows': [], 'subjects': []}}],
#  'links': {'subject_sets.project': {'href': '/projects/{subject_sets.project}',
#    'type': 'projects'},
#   'subject_sets.workflows': {'href': '/workflows?subject_set_id={subject_sets.id}',
#    'type': 'workflows'}},
#  'meta': {'subject_sets': {'page': 1,
#    'page_size': 20,
#    'count': 1,
#    'include': [],
#    'page_count': 1,
#    'previous_page': None,
#    'next_page': None,
#    'first_href': '/subject_sets',
#    'previous_href': None,
#    'next_href': None,
#    'last_href': '/subject_sets'}}}

# %% [markdown]
# ## Get and existing subject set

# %%
subject_set = SubjectSet.find('76903')
subject_set.display_name
# Out:
# '1929 headers'

# %% [markdown]
# ## Upload subjects to a subject set
#
# Generate a list of items from a directory of images. Each item has the following fields:
#
# * `image_path` – full path to image
# * `image_name` – image file name
# * `volume` – volume identifier
# * `volume_number` – numeric
# * `page_number` – numeric

# %%
file_pattern = '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/*header.jpg'
image_files = glob.glob(file_pattern)
data = []
for image_file in image_files:
    image_path = image_file
    image_name = image_file.split('/')[-1]
    volume = re.search(r'(N193-\d+)_', image_name).group(1)
    volume_number = int(volume.split('-')[1])
    page_number = int(re.search(r'N193-\d+_(\d+)', image_name).group(1))
    data.append({'image_path': image_path, 'image_name': image_name, 'volume': volume, 'volume_number': volume_number, 'page_number': page_number})

# %%
# View the results
data
# Out:
# [{'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-116_0246-header.jpg',
#   'image_name': 'N193-116_0246-header.jpg',
#   'volume': 'N193-116',
#   'volume_number': 116,
#   'page_number': 246},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-115_0026-header.jpg',
#   'image_name': 'N193-115_0026-header.jpg',
#   'volume': 'N193-115',
#   'volume_number': 115,
#   'page_number': 26},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-116_0271-header.jpg',
#   'image_name': 'N193-116_0271-header.jpg',
#   'volume': 'N193-116',
#   'volume_number': 116,
#   'page_number': 271},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-115_0011-header.jpg',
#   'image_name': 'N193-115_0011-header.jpg',
#   'volume': 'N193-115',
#   'volume_number': 115,
#   'page_number': 11},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-113_0083-header.jpg',
#   'image_name': 'N193-113_0083-header.jpg',
#   'volume': 'N193-113',
#   'volume_number': 113,
#   'page_number': 83},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-114_0285-header.jpg',
#   'image_name': 'N193-114_0285-header.jpg',
#   'volume': 'N193-114',
#   'volume_number': 114,
#   'page_number': 285},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-115_0132-header.jpg',
#   'image_name': 'N193-115_0132-header.jpg',
#   'volume': 'N193-115',
#   'volume_number': 115,
#   'page_number': 132},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-113_0197-header.jpg',
#   'image_name': 'N193-113_0197-header.jpg',
#   'volume': 'N193-113',
#   'volume_number': 113,
#   'page_number': 197},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-116_0118-header.jpg',
#   'image_name': 'N193-116_0118-header.jpg',
#   'volume': 'N193-116',
#   'volume_number': 116,
#   'page_number': 118},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-115_0105-header.jpg',
#   'image_name': 'N193-115_0105-header.jpg',
#   'volume': 'N193-115',
#   'volume_number': 115,
#   'page_number': 105},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-116_0224-header.jpg',
#   'image_name': 'N193-116_0224-header.jpg',
#   'volume': 'N193-116',
#   'volume_number': 116,
#   'page_number': 224},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-115_0044-header.jpg',
#   'image_name': 'N193-115_0044-header.jpg',
#   'volume': 'N193-115',
#   'volume_number': 115,
#   'page_number': 44},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-116_0059-header.jpg',
#   'image_name': 'N193-116_0059-header.jpg',
#   'volume': 'N193-116',
#   'volume_number': 116,
#   'page_number': 59},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-115_0239-header.jpg',
#   'image_name': 'N193-115_0239-header.jpg',
#   'volume': 'N193-115',
#   'volume_number': 115,
#   'page_number': 239},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-116_0213-header.jpg',
#   'image_name': 'N193-116_0213-header.jpg',
#   'volume': 'N193-116',
#   'volume_number': 116,
#   'page_number': 213},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-115_0073-header.jpg',
#   'image_name': 'N193-115_0073-header.jpg',
#   'volume': 'N193-115',
#   'volume_number': 115,
#   'page_number': 73},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-115_0150-header.jpg',
#   'image_name': 'N193-115_0150-header.jpg',
#   'volume': 'N193-115',
#   'volume_number': 115,
#   'page_number': 150},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-115_0167-header.jpg',
#   'image_name': 'N193-115_0167-header.jpg',
#   'volume': 'N193-115',
#   'volume_number': 115,
#   'page_number': 167},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-116_0307-header.jpg',
#   'image_name': 'N193-116_0307-header.jpg',
#   'volume': 'N193-116',
#   'volume_number': 116,
#   'page_number': 307},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-115_0198-header.jpg',
#   'image_name': 'N193-115_0198-header.jpg',
#   'volume': 'N193-115',
#   'volume_number': 115,
#   'page_number': 198},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-116_0185-header.jpg',
#   'image_name': 'N193-116_0185-header.jpg',
#   'volume': 'N193-116',
#   'volume_number': 116,
#   'page_number': 185},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-114_0052-header.jpg',
#   'image_name': 'N193-114_0052-header.jpg',
#   'volume': 'N193-114',
#   'volume_number': 114,
#   'page_number': 52},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-114_0065-header.jpg',
#   'image_name': 'N193-114_0065-header.jpg',
#   'volume': 'N193-114',
#   'volume_number': 114,
#   'page_number': 65},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-114_0218-header.jpg',
#   'image_name': 'N193-114_0218-header.jpg',
#   'volume': 'N193-114',
#   'volume_number': 114,
#   'page_number': 218},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-114_0146-header.jpg',
#   'image_name': 'N193-114_0146-header.jpg',
#   'volume': 'N193-114',
#   'volume_number': 114,
#   'page_number': 146},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-116_0091-header.jpg',
#   'image_name': 'N193-116_0091-header.jpg',
#   'volume': 'N193-116',
#   'volume_number': 116,
#   'page_number': 91},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-113_0263-header.jpg',
#   'image_name': 'N193-113_0263-header.jpg',
#   'volume': 'N193-113',
#   'volume_number': 113,
#   'page_number': 263},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-113_0254-header.jpg',
#   'image_name': 'N193-113_0254-header.jpg',
#   'volume': 'N193-113',
#   'volume_number': 113,
#   'page_number': 254},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-113_0029-header.jpg',
#   'image_name': 'N193-113_0029-header.jpg',
#   'volume': 'N193-113',
#   'volume_number': 113,
#   'page_number': 29},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-114_0171-header.jpg',
#   'image_name': 'N193-114_0171-header.jpg',
#   'volume': 'N193-114',
#   'volume_number': 114,
#   'page_number': 171},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-114_0030-header.jpg',
#   'image_name': 'N193-114_0030-header.jpg',
#   'volume': 'N193-114',
#   'volume_number': 114,
#   'page_number': 30},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-113_0168-header.jpg',
#   'image_name': 'N193-113_0168-header.jpg',
#   'volume': 'N193-113',
#   'volume_number': 113,
#   'page_number': 168},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-114_0007-header.jpg',
#   'image_name': 'N193-114_0007-header.jpg',
#   'volume': 'N193-114',
#   'volume_number': 114,
#   'page_number': 7},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-113_0201-header.jpg',
#   'image_name': 'N193-113_0201-header.jpg',
#   'volume': 'N193-113',
#   'volume_number': 113,
#   'page_number': 201},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-114_0124-header.jpg',
#   'image_name': 'N193-114_0124-header.jpg',
#   'volume': 'N193-114',
#   'volume_number': 114,
#   'page_number': 124},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-115_0293-header.jpg',
#   'image_name': 'N193-115_0293-header.jpg',
#   'volume': 'N193-115',
#   'volume_number': 115,
#   'page_number': 293},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-114_0113-header.jpg',
#   'image_name': 'N193-114_0113-header.jpg',
#   'volume': 'N193-114',
#   'volume_number': 114,
#   'page_number': 113},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-113_0236-header.jpg',
#   'image_name': 'N193-113_0236-header.jpg',
#   'volume': 'N193-113',
#   'volume_number': 113,
#   'page_number': 236},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-116_0104-header.jpg',
#   'image_name': 'N193-116_0104-header.jpg',
#   'volume': 'N193-116',
#   'volume_number': 116,
#   'page_number': 104},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-115_0119-header.jpg',
#   'image_name': 'N193-115_0119-header.jpg',
#   'volume': 'N193-115',
#   'volume_number': 115,
#   'page_number': 119},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-114_0299-header.jpg',
#   'image_name': 'N193-114_0299-header.jpg',
#   'volume': 'N193-114',
#   'volume_number': 114,
#   'page_number': 299},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-116_0133-header.jpg',
#   'image_name': 'N193-116_0133-header.jpg',
#   'volume': 'N193-116',
#   'volume_number': 116,
#   'page_number': 133},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-116_0010-header.jpg',
#   'image_name': 'N193-116_0010-header.jpg',
#   'volume': 'N193-116',
#   'volume_number': 116,
#   'page_number': 10},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-115_0270-header.jpg',
#   'image_name': 'N193-115_0270-header.jpg',
#   'volume': 'N193-115',
#   'volume_number': 115,
#   'page_number': 270},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-116_0027-header.jpg',
#   'image_name': 'N193-116_0027-header.jpg',
#   'volume': 'N193-116',
#   'volume_number': 116,
#   'page_number': 27},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-115_0247-header.jpg',
#   'image_name': 'N193-115_0247-header.jpg',
#   'volume': 'N193-115',
#   'volume_number': 115,
#   'page_number': 247},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-115_0306-header.jpg',
#   'image_name': 'N193-115_0306-header.jpg',
#   'volume': 'N193-115',
#   'volume_number': 115,
#   'page_number': 306},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-116_0166-header.jpg',
#   'image_name': 'N193-116_0166-header.jpg',
#   'volume': 'N193-116',
#   'volume_number': 116,
#   'page_number': 166},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-114_0086-header.jpg',
#   'image_name': 'N193-114_0086-header.jpg',
#   'volume': 'N193-114',
#   'volume_number': 114,
#   'page_number': 86},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-115_0331-header.jpg',
#   'image_name': 'N193-115_0331-header.jpg',
#   'volume': 'N193-115',
#   'volume_number': 115,
#   'page_number': 331},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-116_0151-header.jpg',
#   'image_name': 'N193-116_0151-header.jpg',
#   'volume': 'N193-116',
#   'volume_number': 116,
#   'page_number': 151},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-116_0072-header.jpg',
#   'image_name': 'N193-116_0072-header.jpg',
#   'volume': 'N193-116',
#   'volume_number': 116,
#   'page_number': 72},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-115_0212-header.jpg',
#   'image_name': 'N193-115_0212-header.jpg',
#   'volume': 'N193-115',
#   'volume_number': 115,
#   'page_number': 212},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-113_0280-header.jpg',
#   'image_name': 'N193-113_0280-header.jpg',
#   'volume': 'N193-113',
#   'volume_number': 113,
#   'page_number': 280},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-116_0238-header.jpg',
#   'image_name': 'N193-116_0238-header.jpg',
#   'volume': 'N193-116',
#   'volume_number': 116,
#   'page_number': 238},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-115_0058-header.jpg',
#   'image_name': 'N193-115_0058-header.jpg',
#   'volume': 'N193-115',
#   'volume_number': 115,
#   'page_number': 58},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-116_0045-header.jpg',
#   'image_name': 'N193-116_0045-header.jpg',
#   'volume': 'N193-116',
#   'volume_number': 116,
#   'page_number': 45},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-115_0225-header.jpg',
#   'image_name': 'N193-115_0225-header.jpg',
#   'volume': 'N193-115',
#   'volume_number': 115,
#   'page_number': 225},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-114_0192-header.jpg',
#   'image_name': 'N193-114_0192-header.jpg',
#   'volume': 'N193-114',
#   'volume_number': 114,
#   'page_number': 192},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-113_0248-header.jpg',
#   'image_name': 'N193-113_0248-header.jpg',
#   'volume': 'N193-113',
#   'volume_number': 113,
#   'page_number': 248},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-114_0310-header.jpg',
#   'image_name': 'N193-114_0310-header.jpg',
#   'volume': 'N193-114',
#   'volume_number': 114,
#   'page_number': 310},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-113_0035-header.jpg',
#   'image_name': 'N193-113_0035-header.jpg',
#   'volume': 'N193-113',
#   'volume_number': 113,
#   'page_number': 35},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-113_0002-header.jpg',
#   'image_name': 'N193-113_0002-header.jpg',
#   'volume': 'N193-113',
#   'volume_number': 113,
#   'page_number': 2},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-115_0090-header.jpg',
#   'image_name': 'N193-115_0090-header.jpg',
#   'volume': 'N193-115',
#   'volume_number': 115,
#   'page_number': 90},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-113_0121-header.jpg',
#   'image_name': 'N193-113_0121-header.jpg',
#   'volume': 'N193-113',
#   'volume_number': 113,
#   'page_number': 121},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-114_0079-header.jpg',
#   'image_name': 'N193-114_0079-header.jpg',
#   'volume': 'N193-114',
#   'volume_number': 114,
#   'page_number': 79},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-114_0204-header.jpg',
#   'image_name': 'N193-114_0204-header.jpg',
#   'volume': 'N193-114',
#   'volume_number': 114,
#   'page_number': 204},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-115_0184-header.jpg',
#   'image_name': 'N193-115_0184-header.jpg',
#   'volume': 'N193-115',
#   'volume_number': 115,
#   'page_number': 184},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-114_0233-header.jpg',
#   'image_name': 'N193-114_0233-header.jpg',
#   'volume': 'N193-114',
#   'volume_number': 114,
#   'page_number': 233},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-116_0199-header.jpg',
#   'image_name': 'N193-116_0199-header.jpg',
#   'volume': 'N193-116',
#   'volume_number': 116,
#   'page_number': 199},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-113_0116-header.jpg',
#   'image_name': 'N193-113_0116-header.jpg',
#   'volume': 'N193-113',
#   'volume_number': 113,
#   'page_number': 116},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-113_0057-header.jpg',
#   'image_name': 'N193-113_0057-header.jpg',
#   'volume': 'N193-113',
#   'volume_number': 113,
#   'page_number': 57},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-116_0292-header.jpg',
#   'image_name': 'N193-116_0292-header.jpg',
#   'volume': 'N193-116',
#   'volume_number': 116,
#   'page_number': 292},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-114_0138-header.jpg',
#   'image_name': 'N193-114_0138-header.jpg',
#   'volume': 'N193-114',
#   'volume_number': 114,
#   'page_number': 138},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-113_0060-header.jpg',
#   'image_name': 'N193-113_0060-header.jpg',
#   'volume': 'N193-113',
#   'volume_number': 113,
#   'page_number': 60},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-114_0266-header.jpg',
#   'image_name': 'N193-114_0266-header.jpg',
#   'volume': 'N193-114',
#   'volume_number': 114,
#   'page_number': 266},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-113_0143-header.jpg',
#   'image_name': 'N193-113_0143-header.jpg',
#   'volume': 'N193-113',
#   'volume_number': 113,
#   'page_number': 143},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-113_0174-header.jpg',
#   'image_name': 'N193-113_0174-header.jpg',
#   'volume': 'N193-113',
#   'volume_number': 113,
#   'page_number': 174},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-114_0251-header.jpg',
#   'image_name': 'N193-114_0251-header.jpg',
#   'volume': 'N193-114',
#   'volume_number': 114,
#   'page_number': 251},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-113_0165-header.jpg',
#   'image_name': 'N193-113_0165-header.jpg',
#   'volume': 'N193-113',
#   'volume_number': 113,
#   'page_number': 165},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-114_0240-header.jpg',
#   'image_name': 'N193-114_0240-header.jpg',
#   'volume': 'N193-114',
#   'volume_number': 114,
#   'page_number': 240},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-114_0277-header.jpg',
#   'image_name': 'N193-114_0277-header.jpg',
#   'volume': 'N193-114',
#   'volume_number': 114,
#   'page_number': 277},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-113_0152-header.jpg',
#   'image_name': 'N193-113_0152-header.jpg',
#   'volume': 'N193-113',
#   'volume_number': 113,
#   'page_number': 152},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-116_0283-header.jpg',
#   'image_name': 'N193-116_0283-header.jpg',
#   'volume': 'N193-116',
#   'volume_number': 116,
#   'page_number': 283},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-114_0129-header.jpg',
#   'image_name': 'N193-114_0129-header.jpg',
#   'volume': 'N193-114',
#   'volume_number': 114,
#   'page_number': 129},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-113_0071-header.jpg',
#   'image_name': 'N193-113_0071-header.jpg',
#   'volume': 'N193-113',
#   'volume_number': 113,
#   'page_number': 71},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-113_0046-header.jpg',
#   'image_name': 'N193-113_0046-header.jpg',
#   'volume': 'N193-113',
#   'volume_number': 113,
#   'page_number': 46},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-115_0195-header.jpg',
#   'image_name': 'N193-115_0195-header.jpg',
#   'volume': 'N193-115',
#   'volume_number': 115,
#   'page_number': 195},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-114_0222-header.jpg',
#   'image_name': 'N193-114_0222-header.jpg',
#   'volume': 'N193-114',
#   'volume_number': 114,
#   'page_number': 222},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-116_0188-header.jpg',
#   'image_name': 'N193-116_0188-header.jpg',
#   'volume': 'N193-116',
#   'volume_number': 116,
#   'page_number': 188},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-113_0107-header.jpg',
#   'image_name': 'N193-113_0107-header.jpg',
#   'volume': 'N193-113',
#   'volume_number': 113,
#   'page_number': 107},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-113_0130-header.jpg',
#   'image_name': 'N193-113_0130-header.jpg',
#   'volume': 'N193-113',
#   'volume_number': 113,
#   'page_number': 130},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-114_0068-header.jpg',
#   'image_name': 'N193-114_0068-header.jpg',
#   'volume': 'N193-114',
#   'volume_number': 114,
#   'page_number': 68},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-114_0215-header.jpg',
#   'image_name': 'N193-114_0215-header.jpg',
#   'volume': 'N193-114',
#   'volume_number': 114,
#   'page_number': 215},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-113_0013-header.jpg',
#   'image_name': 'N193-113_0013-header.jpg',
#   'volume': 'N193-113',
#   'volume_number': 113,
#   'page_number': 13},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-115_0081-header.jpg',
#   'image_name': 'N193-115_0081-header.jpg',
#   'volume': 'N193-115',
#   'volume_number': 115,
#   'page_number': 81},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-113_0259-header.jpg',
#   'image_name': 'N193-113_0259-header.jpg',
#   'volume': 'N193-113',
#   'volume_number': 113,
#   'page_number': 259},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-114_0301-header.jpg',
#   'image_name': 'N193-114_0301-header.jpg',
#   'volume': 'N193-114',
#   'volume_number': 114,
#   'page_number': 301},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-113_0024-header.jpg',
#   'image_name': 'N193-113_0024-header.jpg',
#   'volume': 'N193-113',
#   'volume_number': 113,
#   'page_number': 24},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-115_0049-header.jpg',
#   'image_name': 'N193-115_0049-header.jpg',
#   'volume': 'N193-115',
#   'volume_number': 115,
#   'page_number': 49},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-116_0229-header.jpg',
#   'image_name': 'N193-116_0229-header.jpg',
#   'volume': 'N193-116',
#   'volume_number': 116,
#   'page_number': 229},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-115_0234-header.jpg',
#   'image_name': 'N193-115_0234-header.jpg',
#   'volume': 'N193-115',
#   'volume_number': 115,
#   'page_number': 234},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-116_0054-header.jpg',
#   'image_name': 'N193-116_0054-header.jpg',
#   'volume': 'N193-116',
#   'volume_number': 116,
#   'page_number': 54},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-114_0183-header.jpg',
#   'image_name': 'N193-114_0183-header.jpg',
#   'volume': 'N193-114',
#   'volume_number': 114,
#   'page_number': 183},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-115_0203-header.jpg',
#   'image_name': 'N193-115_0203-header.jpg',
#   'volume': 'N193-115',
#   'volume_number': 115,
#   'page_number': 203},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-116_0063-header.jpg',
#   'image_name': 'N193-116_0063-header.jpg',
#   'volume': 'N193-116',
#   'volume_number': 116,
#   'page_number': 63},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-113_0291-header.jpg',
#   'image_name': 'N193-113_0291-header.jpg',
#   'volume': 'N193-113',
#   'volume_number': 113,
#   'page_number': 291},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-114_0097-header.jpg',
#   'image_name': 'N193-114_0097-header.jpg',
#   'volume': 'N193-114',
#   'volume_number': 114,
#   'page_number': 97},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-116_0140-header.jpg',
#   'image_name': 'N193-116_0140-header.jpg',
#   'volume': 'N193-116',
#   'volume_number': 116,
#   'page_number': 140},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-115_0320-header.jpg',
#   'image_name': 'N193-115_0320-header.jpg',
#   'volume': 'N193-115',
#   'volume_number': 115,
#   'page_number': 320},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-116_0177-header.jpg',
#   'image_name': 'N193-116_0177-header.jpg',
#   'volume': 'N193-116',
#   'volume_number': 116,
#   'page_number': 177},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-115_0317-header.jpg',
#   'image_name': 'N193-115_0317-header.jpg',
#   'volume': 'N193-115',
#   'volume_number': 115,
#   'page_number': 317},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-115_0256-header.jpg',
#   'image_name': 'N193-115_0256-header.jpg',
#   'volume': 'N193-115',
#   'volume_number': 115,
#   'page_number': 256},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-116_0036-header.jpg',
#   'image_name': 'N193-116_0036-header.jpg',
#   'volume': 'N193-116',
#   'volume_number': 116,
#   'page_number': 36},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-115_0261-header.jpg',
#   'image_name': 'N193-115_0261-header.jpg',
#   'volume': 'N193-115',
#   'volume_number': 115,
#   'page_number': 261},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-116_0001-header.jpg',
#   'image_name': 'N193-116_0001-header.jpg',
#   'volume': 'N193-116',
#   'volume_number': 116,
#   'page_number': 1},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-114_0288-header.jpg',
#   'image_name': 'N193-114_0288-header.jpg',
#   'volume': 'N193-114',
#   'volume_number': 114,
#   'page_number': 288},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-116_0122-header.jpg',
#   'image_name': 'N193-116_0122-header.jpg',
#   'volume': 'N193-116',
#   'volume_number': 116,
#   'page_number': 122},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-115_0342-header.jpg',
#   'image_name': 'N193-115_0342-header.jpg',
#   'volume': 'N193-115',
#   'volume_number': 115,
#   'page_number': 342},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-116_0115-header.jpg',
#   'image_name': 'N193-116_0115-header.jpg',
#   'volume': 'N193-116',
#   'volume_number': 116,
#   'page_number': 115},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-115_0108-header.jpg',
#   'image_name': 'N193-115_0108-header.jpg',
#   'volume': 'N193-115',
#   'volume_number': 115,
#   'page_number': 108},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-114_0102-header.jpg',
#   'image_name': 'N193-114_0102-header.jpg',
#   'volume': 'N193-114',
#   'volume_number': 114,
#   'page_number': 102},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-113_0227-header.jpg',
#   'image_name': 'N193-113_0227-header.jpg',
#   'volume': 'N193-113',
#   'volume_number': 113,
#   'page_number': 227},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-113_0210-header.jpg',
#   'image_name': 'N193-113_0210-header.jpg',
#   'volume': 'N193-113',
#   'volume_number': 113,
#   'page_number': 210},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-114_0135-header.jpg',
#   'image_name': 'N193-114_0135-header.jpg',
#   'volume': 'N193-114',
#   'volume_number': 114,
#   'page_number': 135},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-115_0282-header.jpg',
#   'image_name': 'N193-115_0282-header.jpg',
#   'volume': 'N193-115',
#   'volume_number': 115,
#   'page_number': 282},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-114_0016-header.jpg',
#   'image_name': 'N193-114_0016-header.jpg',
#   'volume': 'N193-114',
#   'volume_number': 114,
#   'page_number': 16},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-114_0021-header.jpg',
#   'image_name': 'N193-114_0021-header.jpg',
#   'volume': 'N193-114',
#   'volume_number': 114,
#   'page_number': 21},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-113_0179-header.jpg',
#   'image_name': 'N193-113_0179-header.jpg',
#   'volume': 'N193-113',
#   'volume_number': 113,
#   'page_number': 179},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-113_0304-header.jpg',
#   'image_name': 'N193-113_0304-header.jpg',
#   'volume': 'N193-113',
#   'volume_number': 113,
#   'page_number': 304},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-113_0245-header.jpg',
#   'image_name': 'N193-113_0245-header.jpg',
#   'volume': 'N193-113',
#   'volume_number': 113,
#   'page_number': 245},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-113_0038-header.jpg',
#   'image_name': 'N193-113_0038-header.jpg',
#   'volume': 'N193-113',
#   'volume_number': 113,
#   'page_number': 38},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-114_0160-header.jpg',
#   'image_name': 'N193-114_0160-header.jpg',
#   'volume': 'N193-114',
#   'volume_number': 114,
#   'page_number': 160},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-114_0157-header.jpg',
#   'image_name': 'N193-114_0157-header.jpg',
#   'volume': 'N193-114',
#   'volume_number': 114,
#   'page_number': 157},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-116_0080-header.jpg',
#   'image_name': 'N193-116_0080-header.jpg',
#   'volume': 'N193-116',
#   'volume_number': 116,
#   'page_number': 80},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-113_0272-header.jpg',
#   'image_name': 'N193-113_0272-header.jpg',
#   'volume': 'N193-113',
#   'volume_number': 113,
#   'page_number': 272},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-114_0074-header.jpg',
#   'image_name': 'N193-114_0074-header.jpg',
#   'volume': 'N193-114',
#   'volume_number': 114,
#   'page_number': 74},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-114_0209-header.jpg',
#   'image_name': 'N193-114_0209-header.jpg',
#   'volume': 'N193-114',
#   'volume_number': 114,
#   'page_number': 209},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-115_0189-header.jpg',
#   'image_name': 'N193-115_0189-header.jpg',
#   'volume': 'N193-115',
#   'volume_number': 115,
#   'page_number': 189},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-116_0194-header.jpg',
#   'image_name': 'N193-116_0194-header.jpg',
#   'volume': 'N193-116',
#   'volume_number': 116,
#   'page_number': 194},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-114_0043-header.jpg',
#   'image_name': 'N193-114_0043-header.jpg',
#   'volume': 'N193-114',
#   'volume_number': 114,
#   'page_number': 43},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-115_0176-header.jpg',
#   'image_name': 'N193-115_0176-header.jpg',
#   'volume': 'N193-115',
#   'volume_number': 115,
#   'page_number': 176},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-115_0141-header.jpg',
#   'image_name': 'N193-115_0141-header.jpg',
#   'volume': 'N193-115',
#   'volume_number': 115,
#   'page_number': 141},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-115_0062-header.jpg',
#   'image_name': 'N193-115_0062-header.jpg',
#   'volume': 'N193-115',
#   'volume_number': 115,
#   'page_number': 62},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-116_0202-header.jpg',
#   'image_name': 'N193-116_0202-header.jpg',
#   'volume': 'N193-116',
#   'volume_number': 116,
#   'page_number': 202},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-115_0055-header.jpg',
#   'image_name': 'N193-115_0055-header.jpg',
#   'volume': 'N193-115',
#   'volume_number': 115,
#   'page_number': 55},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-116_0235-header.jpg',
#   'image_name': 'N193-116_0235-header.jpg',
#   'volume': 'N193-116',
#   'volume_number': 116,
#   'page_number': 235},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-115_0228-header.jpg',
#   'image_name': 'N193-115_0228-header.jpg',
#   'volume': 'N193-115',
#   'volume_number': 115,
#   'page_number': 228},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-116_0048-header.jpg',
#   'image_name': 'N193-116_0048-header.jpg',
#   'volume': 'N193-116',
#   'volume_number': 116,
#   'page_number': 48},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-113_0186-header.jpg',
#   'image_name': 'N193-113_0186-header.jpg',
#   'volume': 'N193-113',
#   'volume_number': 113,
#   'page_number': 186},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-116_0109-header.jpg',
#   'image_name': 'N193-116_0109-header.jpg',
#   'volume': 'N193-116',
#   'volume_number': 116,
#   'page_number': 109},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-115_0114-header.jpg',
#   'image_name': 'N193-115_0114-header.jpg',
#   'volume': 'N193-115',
#   'volume_number': 115,
#   'page_number': 114},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-114_0294-header.jpg',
#   'image_name': 'N193-114_0294-header.jpg',
#   'volume': 'N193-114',
#   'volume_number': 114,
#   'page_number': 294},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-115_0123-header.jpg',
#   'image_name': 'N193-115_0123-header.jpg',
#   'volume': 'N193-115',
#   'volume_number': 115,
#   'page_number': 123},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-116_0260-header.jpg',
#   'image_name': 'N193-116_0260-header.jpg',
#   'volume': 'N193-116',
#   'volume_number': 116,
#   'page_number': 260},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-113_0092-header.jpg',
#   'image_name': 'N193-113_0092-header.jpg',
#   'volume': 'N193-113',
#   'volume_number': 113,
#   'page_number': 92},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-115_0037-header.jpg',
#   'image_name': 'N193-115_0037-header.jpg',
#   'volume': 'N193-115',
#   'volume_number': 115,
#   'page_number': 37},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-116_0257-header.jpg',
#   'image_name': 'N193-116_0257-header.jpg',
#   'volume': 'N193-116',
#   'volume_number': 116,
#   'page_number': 257},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-115_0312-header.jpg',
#   'image_name': 'N193-115_0312-header.jpg',
#   'volume': 'N193-115',
#   'volume_number': 115,
#   'page_number': 312},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-116_0172-header.jpg',
#   'image_name': 'N193-116_0172-header.jpg',
#   'volume': 'N193-116',
#   'volume_number': 116,
#   'page_number': 172},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-114_0092-header.jpg',
#   'image_name': 'N193-114_0092-header.jpg',
#   'volume': 'N193-114',
#   'volume_number': 114,
#   'page_number': 92},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-115_0325-header.jpg',
#   'image_name': 'N193-115_0325-header.jpg',
#   'volume': 'N193-115',
#   'volume_number': 115,
#   'page_number': 325},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-116_0145-header.jpg',
#   'image_name': 'N193-116_0145-header.jpg',
#   'volume': 'N193-116',
#   'volume_number': 116,
#   'page_number': 145},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-115_0158-header.jpg',
#   'image_name': 'N193-115_0158-header.jpg',
#   'volume': 'N193-115',
#   'volume_number': 115,
#   'page_number': 158},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-116_0066-header.jpg',
#   'image_name': 'N193-116_0066-header.jpg',
#   'volume': 'N193-116',
#   'volume_number': 116,
#   'page_number': 66},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-115_0206-header.jpg',
#   'image_name': 'N193-115_0206-header.jpg',
#   'volume': 'N193-115',
#   'volume_number': 115,
#   'page_number': 206},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-113_0294-header.jpg',
#   'image_name': 'N193-113_0294-header.jpg',
#   'volume': 'N193-113',
#   'volume_number': 113,
#   'page_number': 294},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-116_0051-header.jpg',
#   'image_name': 'N193-116_0051-header.jpg',
#   'volume': 'N193-116',
#   'volume_number': 116,
#   'page_number': 51},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-115_0231-header.jpg',
#   'image_name': 'N193-115_0231-header.jpg',
#   'volume': 'N193-115',
#   'volume_number': 115,
#   'page_number': 231},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-114_0186-header.jpg',
#   'image_name': 'N193-114_0186-header.jpg',
#   'volume': 'N193-114',
#   'volume_number': 114,
#   'page_number': 186},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-116_0110-header.jpg',
#   'image_name': 'N193-116_0110-header.jpg',
#   'volume': 'N193-116',
#   'volume_number': 116,
#   'page_number': 110},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-115_0347-header.jpg',
#   'image_name': 'N193-115_0347-header.jpg',
#   'volume': 'N193-115',
#   'volume_number': 115,
#   'page_number': 347},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-116_0127-header.jpg',
#   'image_name': 'N193-116_0127-header.jpg',
#   'volume': 'N193-116',
#   'volume_number': 116,
#   'page_number': 127},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-116_0279-header.jpg',
#   'image_name': 'N193-116_0279-header.jpg',
#   'volume': 'N193-116',
#   'volume_number': 116,
#   'page_number': 279},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-115_0019-header.jpg',
#   'image_name': 'N193-115_0019-header.jpg',
#   'volume': 'N193-115',
#   'volume_number': 115,
#   'page_number': 19},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-116_0004-header.jpg',
#   'image_name': 'N193-116_0004-header.jpg',
#   'volume': 'N193-116',
#   'volume_number': 116,
#   'page_number': 4},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-115_0264-header.jpg',
#   'image_name': 'N193-115_0264-header.jpg',
#   'volume': 'N193-115',
#   'volume_number': 115,
#   'page_number': 264},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-116_0033-header.jpg',
#   'image_name': 'N193-116_0033-header.jpg',
#   'volume': 'N193-116',
#   'volume_number': 116,
#   'page_number': 33},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-115_0253-header.jpg',
#   'image_name': 'N193-115_0253-header.jpg',
#   'volume': 'N193-115',
#   'volume_number': 115,
#   'page_number': 253},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-113_0043-header.jpg',
#   'image_name': 'N193-113_0043-header.jpg',
#   'volume': 'N193-113',
#   'volume_number': 113,
#   'page_number': 43},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-113_0209-header.jpg',
#   'image_name': 'N193-113_0209-header.jpg',
#   'volume': 'N193-113',
#   'volume_number': 113,
#   'page_number': 209},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-116_0286-header.jpg',
#   'image_name': 'N193-116_0286-header.jpg',
#   'volume': 'N193-116',
#   'volume_number': 116,
#   'page_number': 286},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-113_0074-header.jpg',
#   'image_name': 'N193-113_0074-header.jpg',
#   'volume': 'N193-113',
#   'volume_number': 113,
#   'page_number': 74},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-114_0272-header.jpg',
#   'image_name': 'N193-114_0272-header.jpg',
#   'volume': 'N193-114',
#   'volume_number': 114,
#   'page_number': 272},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-113_0157-header.jpg',
#   'image_name': 'N193-113_0157-header.jpg',
#   'volume': 'N193-113',
#   'volume_number': 113,
#   'page_number': 157},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-114_0038-header.jpg',
#   'image_name': 'N193-114_0038-header.jpg',
#   'volume': 'N193-114',
#   'volume_number': 114,
#   'page_number': 38},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-113_0160-header.jpg',
#   'image_name': 'N193-113_0160-header.jpg',
#   'volume': 'N193-113',
#   'volume_number': 113,
#   'page_number': 160},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-114_0245-header.jpg',
#   'image_name': 'N193-114_0245-header.jpg',
#   'volume': 'N193-114',
#   'volume_number': 114,
#   'page_number': 245},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-114_0304-header.jpg',
#   'image_name': 'N193-114_0304-header.jpg',
#   'volume': 'N193-114',
#   'volume_number': 114,
#   'page_number': 304},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-113_0021-header.jpg',
#   'image_name': 'N193-113_0021-header.jpg',
#   'volume': 'N193-113',
#   'volume_number': 113,
#   'page_number': 21},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-114_0179-header.jpg',
#   'image_name': 'N193-114_0179-header.jpg',
#   'volume': 'N193-114',
#   'volume_number': 114,
#   'page_number': 179},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-113_0016-header.jpg',
#   'image_name': 'N193-113_0016-header.jpg',
#   'volume': 'N193-113',
#   'volume_number': 113,
#   'page_number': 16},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-116_0099-header.jpg',
#   'image_name': 'N193-116_0099-header.jpg',
#   'volume': 'N193-116',
#   'volume_number': 116,
#   'page_number': 99},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-115_0084-header.jpg',
#   'image_name': 'N193-115_0084-header.jpg',
#   'volume': 'N193-115',
#   'volume_number': 115,
#   'page_number': 84},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-113_0135-header.jpg',
#   'image_name': 'N193-113_0135-header.jpg',
#   'volume': 'N193-113',
#   'volume_number': 113,
#   'page_number': 135},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-114_0210-header.jpg',
#   'image_name': 'N193-114_0210-header.jpg',
#   'volume': 'N193-114',
#   'volume_number': 114,
#   'page_number': 210},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-115_0190-header.jpg',
#   'image_name': 'N193-115_0190-header.jpg',
#   'volume': 'N193-115',
#   'volume_number': 115,
#   'page_number': 190},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-114_0227-header.jpg',
#   'image_name': 'N193-114_0227-header.jpg',
#   'volume': 'N193-114',
#   'volume_number': 114,
#   'page_number': 227},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-113_0102-header.jpg',
#   'image_name': 'N193-113_0102-header.jpg',
#   'volume': 'N193-113',
#   'volume_number': 113,
#   'page_number': 102},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-116_0230-header.jpg',
#   'image_name': 'N193-116_0230-header.jpg',
#   'volume': 'N193-116',
#   'volume_number': 116,
#   'page_number': 230},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-115_0050-header.jpg',
#   'image_name': 'N193-115_0050-header.jpg',
#   'volume': 'N193-115',
#   'volume_number': 115,
#   'page_number': 50},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-116_0207-header.jpg',
#   'image_name': 'N193-116_0207-header.jpg',
#   'volume': 'N193-116',
#   'volume_number': 116,
#   'page_number': 207},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-115_0067-header.jpg',
#   'image_name': 'N193-115_0067-header.jpg',
#   'volume': 'N193-115',
#   'volume_number': 115,
#   'page_number': 67},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-113_0288-header.jpg',
#   'image_name': 'N193-113_0288-header.jpg',
#   'volume': 'N193-113',
#   'volume_number': 113,
#   'page_number': 288},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-115_0339-header.jpg',
#   'image_name': 'N193-115_0339-header.jpg',
#   'volume': 'N193-115',
#   'volume_number': 115,
#   'page_number': 339},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-116_0159-header.jpg',
#   'image_name': 'N193-116_0159-header.jpg',
#   'volume': 'N193-116',
#   'volume_number': 116,
#   'page_number': 159},
# ...
#   'image_name': 'N193-114_0300-header.jpg',
#   'volume': 'N193-114',
#   'volume_number': 114,
#   'page_number': 300},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-115_0177-header.jpg',
#   'image_name': 'N193-115_0177-header.jpg',
#   'volume': 'N193-115',
#   'volume_number': 115,
#   'page_number': 177},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-115_0140-header.jpg',
#   'image_name': 'N193-115_0140-header.jpg',
#   'volume': 'N193-115',
#   'volume_number': 115,
#   'page_number': 140},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-116_0203-header.jpg',
#   'image_name': 'N193-116_0203-header.jpg',
#   'volume': 'N193-116',
#   'volume_number': 116,
#   'page_number': 203},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-115_0063-header.jpg',
#   'image_name': 'N193-115_0063-header.jpg',
#   'volume': 'N193-115',
#   'volume_number': 115,
#   'page_number': 63},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-116_0049-header.jpg',
#   'image_name': 'N193-116_0049-header.jpg',
#   'volume': 'N193-116',
#   'volume_number': 116,
#   'page_number': 49},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-115_0229-header.jpg',
#   'image_name': 'N193-115_0229-header.jpg',
#   'volume': 'N193-115',
#   'volume_number': 115,
#   'page_number': 229},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-116_0234-header.jpg',
#   'image_name': 'N193-116_0234-header.jpg',
#   'volume': 'N193-116',
#   'volume_number': 116,
#   'page_number': 234},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-115_0054-header.jpg',
#   'image_name': 'N193-115_0054-header.jpg',
#   'volume': 'N193-115',
#   'volume_number': 115,
#   'page_number': 54},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-115_0115-header.jpg',
#   'image_name': 'N193-115_0115-header.jpg',
#   'volume': 'N193-115',
#   'volume_number': 115,
#   'page_number': 115},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-116_0108-header.jpg',
#   'image_name': 'N193-116_0108-header.jpg',
#   'volume': 'N193-116',
#   'volume_number': 116,
#   'page_number': 108},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-113_0187-header.jpg',
#   'image_name': 'N193-113_0187-header.jpg',
#   'volume': 'N193-113',
#   'volume_number': 113,
#   'page_number': 187},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-115_0122-header.jpg',
#   'image_name': 'N193-115_0122-header.jpg',
#   'volume': 'N193-115',
#   'volume_number': 115,
#   'page_number': 122},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-114_0295-header.jpg',
#   'image_name': 'N193-114_0295-header.jpg',
#   'volume': 'N193-114',
#   'volume_number': 114,
#   'page_number': 295},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-113_0093-header.jpg',
#   'image_name': 'N193-113_0093-header.jpg',
#   'volume': 'N193-113',
#   'volume_number': 113,
#   'page_number': 93},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-116_0261-header.jpg',
#   'image_name': 'N193-116_0261-header.jpg',
#   'volume': 'N193-116',
#   'volume_number': 116,
#   'page_number': 261},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-115_0001-header.jpg',
#   'image_name': 'N193-115_0001-header.jpg',
#   'volume': 'N193-115',
#   'volume_number': 115,
#   'page_number': 1},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-116_0256-header.jpg',
#   'image_name': 'N193-116_0256-header.jpg',
#   'volume': 'N193-116',
#   'volume_number': 116,
#   'page_number': 256},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-115_0036-header.jpg',
#   'image_name': 'N193-115_0036-header.jpg',
#   'volume': 'N193-115',
#   'volume_number': 115,
#   'page_number': 36},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-113_0226-header.jpg',
#   'image_name': 'N193-113_0226-header.jpg',
#   'volume': 'N193-113',
#   'volume_number': 113,
#   'page_number': 226},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-114_0103-header.jpg',
#   'image_name': 'N193-114_0103-header.jpg',
#   'volume': 'N193-114',
#   'volume_number': 114,
#   'page_number': 103},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-115_0283-header.jpg',
#   'image_name': 'N193-115_0283-header.jpg',
#   'volume': 'N193-115',
#   'volume_number': 115,
#   'page_number': 283},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-114_0134-header.jpg',
#   'image_name': 'N193-114_0134-header.jpg',
#   'volume': 'N193-114',
#   'volume_number': 114,
#   'page_number': 134},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-113_0211-header.jpg',
#   'image_name': 'N193-113_0211-header.jpg',
#   'volume': 'N193-113',
#   'volume_number': 113,
#   'page_number': 211},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-114_0017-header.jpg',
#   'image_name': 'N193-114_0017-header.jpg',
#   'volume': 'N193-114',
#   'volume_number': 114,
#   'page_number': 17},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-113_0305-header.jpg',
#   'image_name': 'N193-113_0305-header.jpg',
#   'volume': 'N193-113',
#   'volume_number': 113,
#   'page_number': 305},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-114_0020-header.jpg',
#   'image_name': 'N193-114_0020-header.jpg',
#   'volume': 'N193-114',
#   'volume_number': 114,
#   'page_number': 20},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-113_0178-header.jpg',
#   'image_name': 'N193-113_0178-header.jpg',
#   'volume': 'N193-113',
#   'volume_number': 113,
#   'page_number': 178},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-113_0039-header.jpg',
#   'image_name': 'N193-113_0039-header.jpg',
#   'volume': 'N193-113',
#   'volume_number': 113,
#   'page_number': 39},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-114_0161-header.jpg',
#   'image_name': 'N193-114_0161-header.jpg',
#   'volume': 'N193-114',
#   'volume_number': 114,
#   'page_number': 161},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-113_0244-header.jpg',
#   'image_name': 'N193-113_0244-header.jpg',
#   'volume': 'N193-113',
#   'volume_number': 113,
#   'page_number': 244},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-113_0273-header.jpg',
#   'image_name': 'N193-113_0273-header.jpg',
#   'volume': 'N193-113',
#   'volume_number': 113,
#   'page_number': 273},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-116_0081-header.jpg',
#   'image_name': 'N193-116_0081-header.jpg',
#   'volume': 'N193-116',
#   'volume_number': 116,
#   'page_number': 81},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-114_0156-header.jpg',
#   'image_name': 'N193-114_0156-header.jpg',
#   'volume': 'N193-114',
#   'volume_number': 114,
#   'page_number': 156},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-114_0208-header.jpg',
#   'image_name': 'N193-114_0208-header.jpg',
#   'volume': 'N193-114',
#   'volume_number': 114,
#   'page_number': 208},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-114_0075-header.jpg',
#   'image_name': 'N193-114_0075-header.jpg',
#   'volume': 'N193-114',
#   'volume_number': 114,
#   'page_number': 75},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-114_0042-header.jpg',
#   'image_name': 'N193-114_0042-header.jpg',
#   'volume': 'N193-114',
#   'volume_number': 114,
#   'page_number': 42},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-116_0195-header.jpg',
#   'image_name': 'N193-116_0195-header.jpg',
#   'volume': 'N193-116',
#   'volume_number': 116,
#   'page_number': 195},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-115_0188-header.jpg',
#   'image_name': 'N193-115_0188-header.jpg',
#   'volume': 'N193-115',
#   'volume_number': 115,
#   'page_number': 188},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-113_0148-header.jpg',
#   'image_name': 'N193-113_0148-header.jpg',
#   'volume': 'N193-113',
#   'volume_number': 113,
#   'page_number': 148},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-114_0010-header.jpg',
#   'image_name': 'N193-114_0010-header.jpg',
#   'volume': 'N193-114',
#   'volume_number': 114,
#   'page_number': 10},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-114_0027-header.jpg',
#   'image_name': 'N193-114_0027-header.jpg',
#   'volume': 'N193-114',
#   'volume_number': 114,
#   'page_number': 27},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-113_0302-header.jpg',
#   'image_name': 'N193-113_0302-header.jpg',
#   'volume': 'N193-113',
#   'volume_number': 113,
#   'page_number': 302},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-114_0104-header.jpg',
#   'image_name': 'N193-114_0104-header.jpg',
#   'volume': 'N193-114',
#   'volume_number': 114,
#   'page_number': 104},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-113_0221-header.jpg',
#   'image_name': 'N193-113_0221-header.jpg',
#   'volume': 'N193-113',
#   'volume_number': 113,
#   'page_number': 221},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-116_0299-header.jpg',
#   'image_name': 'N193-116_0299-header.jpg',
#   'volume': 'N193-116',
#   'volume_number': 116,
#   'page_number': 299},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-113_0216-header.jpg',
#   'image_name': 'N193-113_0216-header.jpg',
#   'volume': 'N193-113',
#   'volume_number': 113,
#   'page_number': 216},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-115_0284-header.jpg',
#   'image_name': 'N193-115_0284-header.jpg',
#   'volume': 'N193-115',
#   'volume_number': 115,
#   'page_number': 284},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-114_0133-header.jpg',
#   'image_name': 'N193-114_0133-header.jpg',
#   'volume': 'N193-114',
#   'volume_number': 114,
#   'page_number': 133},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-114_0072-header.jpg',
#   'image_name': 'N193-114_0072-header.jpg',
#   'volume': 'N193-114',
#   'volume_number': 114,
#   'page_number': 72},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-114_0238-header.jpg',
#   'image_name': 'N193-114_0238-header.jpg',
#   'volume': 'N193-114',
#   'volume_number': 114,
#   'page_number': 238},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-114_0045-header.jpg',
#   'image_name': 'N193-114_0045-header.jpg',
#   'volume': 'N193-114',
#   'volume_number': 114,
#   'page_number': 45},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-116_0192-header.jpg',
#   'image_name': 'N193-116_0192-header.jpg',
#   'volume': 'N193-116',
#   'volume_number': 116,
#   'page_number': 192},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-113_0243-header.jpg',
#   'image_name': 'N193-113_0243-header.jpg',
#   'volume': 'N193-113',
#   'volume_number': 113,
#   'page_number': 243},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-114_0166-header.jpg',
#   'image_name': 'N193-114_0166-header.jpg',
#   'volume': 'N193-114',
#   'volume_number': 114,
#   'page_number': 166},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-116_0086-header.jpg',
#   'image_name': 'N193-116_0086-header.jpg',
#   'volume': 'N193-116',
#   'volume_number': 116,
#   'page_number': 86},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-114_0151-header.jpg',
#   'image_name': 'N193-114_0151-header.jpg',
#   'volume': 'N193-114',
#   'volume_number': 114,
#   'page_number': 151},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-113_0009-header.jpg',
#   'image_name': 'N193-113_0009-header.jpg',
#   'volume': 'N193-113',
#   'volume_number': 113,
#   'page_number': 9},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-113_0274-header.jpg',
#   'image_name': 'N193-113_0274-header.jpg',
#   'volume': 'N193-113',
#   'volume_number': 113,
#   'page_number': 274},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-115_0219-header.jpg',
#   'image_name': 'N193-115_0219-header.jpg',
#   'volume': 'N193-115',
#   'volume_number': 115,
#   'page_number': 219},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-116_0079-header.jpg',
#   'image_name': 'N193-116_0079-header.jpg',
#   'volume': 'N193-116',
#   'volume_number': 116,
#   'page_number': 79},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-115_0064-header.jpg',
#   'image_name': 'N193-115_0064-header.jpg',
#   'volume': 'N193-115',
#   'volume_number': 115,
#   'page_number': 64},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-116_0204-header.jpg',
#   'image_name': 'N193-116_0204-header.jpg',
#   'volume': 'N193-116',
#   'volume_number': 116,
#   'page_number': 204},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-115_0053-header.jpg',
#   'image_name': 'N193-115_0053-header.jpg',
#   'volume': 'N193-115',
#   'volume_number': 115,
#   'page_number': 53},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-116_0233-header.jpg',
#   'image_name': 'N193-116_0233-header.jpg',
#   'volume': 'N193-116',
#   'volume_number': 116,
#   'page_number': 233},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-114_0199-header.jpg',
#   'image_name': 'N193-114_0199-header.jpg',
#   'volume': 'N193-114',
#   'volume_number': 114,
#   'page_number': 199},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-116_0310-header.jpg',
#   'image_name': 'N193-116_0310-header.jpg',
#   'volume': 'N193-116',
#   'volume_number': 116,
#   'page_number': 310},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-115_0170-header.jpg',
#   'image_name': 'N193-115_0170-header.jpg',
#   'volume': 'N193-115',
#   'volume_number': 115,
#   'page_number': 170},
#  {'image_path': '/Volumes/Workspace/mycode/stock-exchange/notebooks/processed/1929/headers/N193-115_0147-header.jpg',
#   'image_name': 'N193-115_0147-header.jpg',
#   'volume': 'N193-115',
#   'volume_number': 115,
#   'page_number': 147},
#  ...]

# %% [markdown]
# Loop through the metadata creating new Zooniverse subjects. The images are resized before they are added to the subjects.

# %%
new_subjects = []
for item in data:
    # New Zooniverse subject
    subject = Subject()
    
    # Link subject to project
    subject.links.project = project
    
    # Open the image
    img = Image.open(item['image_path'])
    w, h = img.size
    
    # Get the resize ratio based on a maximum width of 2000 px
    ratio = 2000 / w
    
    # Resize image using the ratio
    img = img.resize((int(w*ratio), int(h*ratio)), Image.LANCZOS)
    
    # Create a bytes object and save the image to it
    b = io.BytesIO()
    img.save(b, 'JPEG')
    b.seek(0)
    
    # Add the bytes object to the subject
    subject.add_location(b)
    
    # Add metadata to the subject
    subject.metadata['image'] = item['image_name']
    subject.metadata['volume'] = item['volume']
    subject.metadata['volume_number'] = item['volume_number']
    subject.metadata['page_number'] = item['page_number']
    subject.metadata['year'] = 1929
    
    # Save the subject
    subject.save()
    
    # Add to the list of subjects
    new_subjects.append(subject)

# %%
# Save the list of subjects to the subject set
subject_set.add(new_subjects)
